# %% [markdown]
# ## 內容區

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\LU\Desktop\python

# %%
import pandas as pd
tab=pd.read_excel('Sample_with_names.xlsx')
print(tab.columns)
# Out:
# Index(['news_ID', 'hyperlink', 'content', 'name'], dtype='object')

# %%
def function(a): 
    if 'nownews' in a: 
        return 1
    else: 
        return 0 
#div,p分流
tab['test'] = tab.apply(lambda x: function(x.hyperlink), axis = 1)

# %%
def function(a) :
    if 'nownews' in a:
        return '00'
    elif 'ltn' in a:
        return '01'
    elif 'chinatimes' in a:
        return '02'
    elif 'setn' in a:
        return '03'
    elif 'yahoo' in a:
        return '04'
    elif 'mirror' in a:
        return '05'
    elif 'ettoday' in a:
        return '06'
    elif 'cna' in a:
        return '07'
    elif 'udn' in a:
        return '08'
    elif 'tvbs' in a:
        return '09'
    elif 'nextmag' in a:
        return '10'
    elif 'businesstoday' in a:
        return '11'
    elif 'hk01' in a:
        return '12'
    elif 'storm' in a:
        return '13'
    elif 'on.cc' in a:
        return '14'
    elif 'ebc'in a:
        return '15'
    #div,p分流
tab['test1'] = tab.apply(lambda x: function(x.hyperlink), axis = 1)

# %%
import requests
import re
from requests.packages import urllib3
urllib3.disable_warnings()
headers={
    'User-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36'
}
from bs4 import BeautifulSoup
def function(a):
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find_all('title')
        r='%s'*len(r) % tuple(r) 
        r=r.strip()
        r1= re.compile(r'[<title> /]')
        r= r1.sub('' ,r )
        return r
tab['title'] = tab.apply(lambda x: function(x.hyperlink), axis = 1)

# %%
def function(a,b): 
    if b=='00': #Nownews
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.get_text() 
        r=r.split('(function (d, a, b, l, e, _)')[0].split('NOWnews關鍵字')[0].split('insertBefore(s, el)')[1].split('\n大')[1]
        r=r.strip()
        r1= re.compile(r'[<p> /]')
        r= r1.sub('' ,r )
        return r
    elif b=='01': #自由
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find_all('p')
        r='%s'*len(r) % tuple(r) 
        r=r.strip()
        r1= re.compile(r'[<p> /]')
        r= r1.sub('' ,r )
        return r
    elif b=='02' : #中時
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find_all('p')
        r='%s'*len(r) % tuple(r)
        r=r.split('<strong>中時電子報對留言')[0]
        r1= re.compile(r'</p>')
        r= r1.sub('' , r)
        r1= re.compile(r'<p>')
        r= r1.sub('' , r)
        return r
    elif b=='03' : #三立
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find_all('p')
        r='%s'*len(r) % tuple(r)
        r=r.strip()
        r1= re.compile(r'[<p> / br]')
        r= r1.sub('' ,r )
        return r
    elif b=='04' : #yahoo
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find('p')
        r='%s'*len(r) % tuple(r)
        return r
    elif b=='05': #鏡報
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find_all('p')        
        r='%s'*len(r) % tuple(r)
        r=r.split('</span>')[1].split('<p class="updated-time">')[0]
        r1= re.compile(r'</p>')
        r= r1.sub('' , r)
        r1= re.compile(r'<p>')
        r= r1.sub('' , r)
        return r
    elif b=='06': #ETToday
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find_all('p')
        r='%s'*len(r) % tuple(r)
        r=r.split('</p><p><span style="color' )[0]
        r=r.strip()
        r1= re.compile(r'[<p> /]')
        r= r1.sub('' ,r )
        return r
    elif b=='07': #中央社
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find_all('p')
        r='%s'*len(r) % tuple(r)
        r=r.split('電）' )[1].split('（編輯')[0]
        r=r.strip()
        r1= re.compile(r'[<p> /]')
        r= r1.sub('' ,r )
        return r
    elif b=='08': #聯合報
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find_all('p')
        r='%s'*len(r) % tuple(r)
        r=r.split('<p style="margin-bottom' )[0]
        r=r.strip()
        r1= re.compile(r'[<p> / ahref="searchtagging2]')
        r= r1.sub('' ,r )
        return r
    elif b=='09': #tvbs
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find_all('p')
        r='%s'*len(r) % tuple(r)
        r=r.split('>大<')[1]
        r=r.strip()
        r1= re.compile(r'[<p> / br]')
        r= r1.sub('' ,r )
        return r
    elif b=='10': #nextmag
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find_all('p')
        r='%s'*len(r) % tuple(r) 
        r=r.strip()
        r1= re.compile(r'[<p> /]')
        r= r1.sub('' ,r )
        return r
    elif b=='11': #businesstoday
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find_all('p')
        r='%s'*len(r) % tuple(r)
        r=r.split('期</a>')[1].split('服務')[0]
        r=r.strip()
        r1= re.compile(r'[<p> /]')
        r= r1.sub('' ,r )
        return r
    elif b=='12': #hk01
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find_all('p')
        r='%s'*len(r) % tuple(r)
        r=r.split('註冊')[1].split('案件編號')[0]
        r=r.strip()
        r1= re.compile(r'[<p> /] ')
        r= r1.sub('' ,r )
        return r
    elif b=='13': #風傳媒
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find_all('p')
        r='%s'*len(r) % tuple(r)
        r=r.split('</p><p aid="61">')[1].split('喜歡這篇文章嗎？')[0]
        r=r.strip()
        r1= re.compile(r'[<p> /] ')
        r= r1.sub('' ,r )
        return r
    elif b=='14': #oncc
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find_all('p')
        r='%s'*len(r) % tuple(r)
        r=r.strip()
        r1= re.compile(r'[<p> / br] ')
        r= r1.sub('' ,r )
        return r
    elif b=='15': #ebc
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find_all('p')
        r='%s'*len(r) % tuple(r)
        r=r.strip()
        r1= re.compile(r'[<p> / br]')
        r= r1.sub('' ,r )
        return r
    else:
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find_all('p')
        r='%s'*len(r) % tuple(r) 
        r=r.strip()
        r1= re.compile(r'[<p> /]')
        r= r1.sub('' ,r )
        return r
#div,p分流
tab['result'] = tab.apply(lambda x: function(x.hyperlink,x.test1), axis = 1)

# %%
tab.to_csv('jade_v2.csv', index = False)

# %% [markdown]
# ## 以上程式

# %%
    elif b=='03' : #三立
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find_all('p')
        r='%s'*len(r) % tuple(r)
        r=r.strip()
        r1= re.compile(r'[<p> / br]')
        r= r1.sub('' ,r )
        return r
    elif b=='04' : #yahoo
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find('p')
        r='%s'*len(r) % tuple(r)
        return r
    elif b=='05': #鏡報
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find_all('p')        
        r='%s'*len(r) % tuple(r)
        r=r.split('</span>')[1].split('<p class="updated-time">')[0]
        r1= re.compile(r'</p>')
        r= r1.sub('' , r)
        r1= re.compile(r'<p>')
        r= r1.sub('' , r)
        return r
    elif b=='06': #ETToday
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find_all('p')
        r='%s'*len(r) % tuple(r)
        r=r.split('</p><p><span style="color' )[0]
        r=r.strip()
        r1= re.compile(r'[<p> /]')
        r= r1.sub('' ,r )
        return r
    elif b=='07': #中央社
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find_all('p')
        r='%s'*len(r) % tuple(r)
        r=r.split('電）' )[1].split('（編輯')[0]
        r=r.strip()
        r1= re.compile(r'[<p> /]')
        r= r1.sub('' ,r )
        return r
    elif b=='08': #聯合報
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find_all('p')
        r='%s'*len(r) % tuple(r)
        r=r.split('<p style="margin-bottom' )[0]
        r=r.strip()
        r1= re.compile(r'[<p> / ahref="searchtagging2]')
        r= r1.sub('' ,r )
        return r
    elif b=='09': #tvbs
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find_all('p')
        r='%s'*len(r) % tuple(r)
        r=r.split('>大<')[1]
        r=r.strip()
        r1= re.compile(r'[<p> / br]')
        r= r1.sub('' ,r )
        return r
    elif b=='10': #nextmag
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find_all('p')
        r='%s'*len(r) % tuple(r)
        r=r.split('</span> </strong> </p><p></p><p>')[1].split('（撰文：' )[0]
        r=r.strip()
        r1= re.compile(r'[<p> /]')
        r= r1.sub('' ,r )
        return r
    elif b=='11': #businesstoday
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find_all('p')
        r='%s'*len(r) % tuple(r)
        r=r.split('期</a>')[1].split('服務')[0]
        r=r.strip()
        r1= re.compile(r'[<p> /]')
        r= r1.sub('' ,r )
        return r
    elif b=='12': #hk01
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find_all('p')
        r='%s'*len(r) % tuple(r)
        r=r.split('註冊')[1].split('案件編號')[0]
        r=r.strip()
        r1= re.compile(r'[<p> /] ')
        r= r1.sub('' ,r )
        return r
    elif b=='13': #風傳媒
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find_all('p')
        r='%s'*len(r) % tuple(r)
        r=r.split('</p><p aid="61">')[1].split('喜歡這篇文章嗎？')[0]
        r=r.strip()
        r1= re.compile(r'[<p> /] ')
        r= r1.sub('' ,r )
        return r
    elif b=='14': #oncc
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find_all('p')
        r='%s'*len(r) % tuple(r)
        r=r.strip()
        r1= re.compile(r'[<p> / br] ')
        r= r1.sub('' ,r )
        return r
    elif b=='15': #ebc
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find_all('p')
        r='%s'*len(r) % tuple(r)
        r=r.strip()
        r1= re.compile(r'[<p> / br]')
        r= r1.sub('' ,r )
        return r
    else:
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find_all('p')
        r='%s'*len(r) % tuple(r) 
        r=r.strip()
        r1= re.compile(r'[<p> /]')
        r= r1.sub('' ,r )
        return r

# %%
def function(a,b): 
    if b==0:
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.find_all('p')
        r='%s'*len(r) % tuple(r) 
        r=r.strip()
        r1= re.compile(r'[<p> /]')
        r= r1.sub('' ,r )
        return r
    else:
        r=requests.get(a,verify=False,headers=headers)
        r.encoding='utf-8'
        r=BeautifulSoup(r.text,'lxml') #以lxml為解碼器
        r=r.get_text() 
        r=r.split('(function (d, a, b, l, e, _)')[0].split('NOWnews關鍵字')[0].split('insertBefore(s, el)')[1].split('\n大')[1]
        r=r.strip()
        r1= re.compile(r'[<p> /]')
        r= r1.sub('' ,r )
        return r
#div,p分流
tab['result'] = tab.apply(lambda x: function(x.hyperlink,x.test), axis = 1)

# %% [markdown]
# ## 驗證分流結果

# %%
print(tab.hyperlink[69])
# Out:
# https://www.nownews.com/news/20190802/3537141/

# %%
print(tab.result[69])
# Out:
# （中央社記者林長順台北2日電）台北地檢署偵辦菸品走私案，昨天約談華航前資深副總羅雅美、前空品處副總邱彰信、協理于堯等8人。檢方複訊後，今天凌晨諭令邱彰信新台幣70萬元交保，羅雅美請回。檢方為釐清華航辦理專機免稅菸品買賣流程，昨天約談羅雅美、邱彰信、于堯、黃川禎等8人說明，由於羅、邱日前被民眾告發瀆職等罪，檢察官以他字案被告約談兩人說明。于堯則被轉為貪污案被告。檢察官複訊後，昨天晚間先諭令于堯50萬元交保，今天凌晨諭令邱彰信70萬元交保、羅雅美請回。（編輯：唐聲揚）1080802

# %%
#自由時報,鏡傳媒,Nownws,中時,三立, yahoo,ETToday,中央社,聯合,TVBS,壹週刊(Nextmag),今周刊(businesstoday),HK01,風傳媒(storm)
#on.cc東網, ebc
r=soup.find('title')
r=r.text
r=r.strip()
r1= re.compile(r'[<title> /]')
r= r1.sub('' ,r )
print(r)
# Out:
# 再破世紀毒案　越南警檢2.1噸冰毒K仔拘3人｜即時新聞｜兩岸｜on.cc東網

# %%
#自由時報內容
import re
r=soup.find_all('p')
r='%s'*len(r) % tuple(r)
r=r.split('報導')[1].split('<p class="appE1121">')[0]
r=r.strip()
r1= re.compile(r'</p>')
r= r1.sub('' , r)
r1=re.compile(r'<p>')
r= r1.sub('' , r)
r1=re.compile(r'<p class="before_ir" style="text-align: center; display: none;">請繼續往下閱讀...<p class="after_ir" style="display: none;">')
r=r1.sub('',r)
print(r)
# Out:
# 〕12年前爆發的花蓮縣壽豐鄉鯉魚潭風景區的「綠湖國際大飯店」開發弊案，業者王桂霜為讓計畫案順利進行，以250萬元行賄時任內政部都市計畫委員會委員李威儀與其學生藍秀琪；經法院12年審理，2017年12月花蓮高分院更三審判李威儀12年徒刑、藍秀琪9年，皆褫奪公權6年，王桂霜1年9月、褫奪公權1年；最高法院日前駁回上訴，全案全部定讞。此開發計畫在花蓮縣都市計畫委員會審查時，曾5度闖關未過，1999年起死回生，業者雙聯投資實業公司董事長王桂霜，申請將鯉魚潭的22公頃公園等用地，變更為旅館用地與停車場，隔年8月花蓮縣政府通過變更計畫案，函送內政部都市計畫委員會審議。都委會專案小組赴現場勘查後，前3次專案會議都明確表達反對之意，強烈質疑公園綠地面積只占6.4%，未達10%的最低法定下限，更何況是風景特定區，認為不宜輕率將綠地變更為建地。王桂霜為求解套，透過花蓮縣政府承辦技士居中介紹，與負責審查此案的的時任內政部都委會專案小組召集人、台科大建築系副教授李威儀搭上線，相約在第4次專案會議的前1天，於台北市西華飯店碰面。李威儀在西華當面向王桂霜提議，可利用他的碩士在職專班學生藍秀琪當「白手套」，由藍秀琪開設的公司來負責規劃開發計畫書，李向王索賄250萬元，分3期付清。李與藍虛構「綠湖觀光飯店規劃案」，試圖以規劃設計費的名義讓賄款合法化，李並教唆都委會2名承辦人登載不實資料，企圖矇混過關。幾經運作，李威儀趕在他的委員任期屆滿之前，於2001年5月、6月連開最後2次專案小組會議，做成「尊重花蓮縣府意見，建議本案原則同意變更」的審查意見，送內政部審議，並在卸任後列席委員會報告，企圖說服與會人士支持。調查局東機站事後獲報，報告花蓮地檢署指揮偵辦，2007年起訴李威儀等人。案經法院審理12年，李威儀等人一度獲判無罪，但被撤銷發回，更三審依違背職務收賄罪，判李、藍各12年、9年徒刑，王桂霜以行賄罪判刑1年9月。最高法院認定更三審判決沒有違誤，駁回上訴確定。

# %%
#鏡報內容
import re
r=soup.find_all('p')
r='%s'*len(r) % tuple(r)
r=r.split('</span>')[1].split('<p class="updated-time">')[0]
r1= re.compile(r'</p>')
。但陳因自己也很想選主席，隨後便將110萬元還給黃，佯稱其餘4人不願意，但自己還是會支持黃，投票結果，黃僅得3票，陳則以8票當上主席。黃不滿陳倒戈，還當選主席，1月即向彰化縣調查站檢舉並全盤托出，指控陳涉嫌每票30萬元買票當選，全案經檢察官指揮偵辦，當時，陳坦承收到黃交付110萬元，但稱不敢買票才將錢退還，堅決否認當選主席有行賄。陳因涉案重大且有串證之虞，遭聲押獲准，目前仍羈押彰化看守所。

# %%
#Yahoo內容
from bs4 import BeautifulSoup
r.encoding='utf-8'
soup=BeautifulSoup(r.text,'lxml') #以liml為解碼器
r=soup.find('p')
r='%s'*len(r) % tuple(r)
print(r)

# %%
#東森ebc
import re
from bs4 import BeautifulSoup
r.encoding='utf-8'
soup=BeautifulSoup(r.text,'lxml') #以liml為解碼器
r=soup.find_all('p')
r='%s'*len(r) % tuple(r)
r=r.strip()
r1= re.compile(r'[<p> / br]')
r= r1.sub('' ,r )
print(r)
# Out:
# 自稱房產幽默大師的王派宏，涉吸金捲款25億落跑！他自稱炒房專家，在全台授課分享理財，卻遭指控，4月28號突然聯繫不上，也沒上課，顧問公司以為他發生危險立刻報案，但人卻已經離開台灣，被害的投資人懷疑，王派宏已經捲款，急忙報警追人。ahef="htt:it.ly35BsLq"★【500萬粉絲就差你一個】a ▼自稱房產幽默大師的王派宏，涉吸金捲款25億落跑！（圖／東森新聞）imgsc="htts:img.news.ec.net.twEcNewsnews201905021556789902_15517.JPG"style="width:100%;height:100%;"
# 被害人小吳：「他有提到從台灣，帶黃金到印度，ㄧ個月會有3%（分紅），除了他介紹以外，透過很多學員都已經開始投資，而且過去2、3年都ok，都有如期拿到利息，的確有固定利息，從小金額100多萬，到後面越投越多，老師也一直鼓吹，所以投到後來變1千多萬。」 40多歲的受害人，因為遭裁員決定把畢生積蓄，拿去投資黃金變粉末賣到印度，尤其王派宏還鼓吹學員，甚至還簽了本票讓所有人深信不疑。 ▼自稱炒房專家，在全台授課分享理財，卻遭指控4月28號突然聯繫不上。（圖／東森新聞）imgsc="htts:img.news.ec.net.twEcNewsnews201905021556789902_79210.JPG"style="width:100%;height:100%;"
# 被害人小吳：「有跟我們看工廠的狀況，有看到實際的，每個月有拿到利息，外面很多投資案，第一個他是老師，很多學員畢竟時間很久了也有出過書，被人家採訪過，他又開本票，其他投資案沒有的，給了我們很大的放心。」 ▼知名度加上人人說好，以為是一線希望反而血本無歸。（圖／東森新聞）imgsc="htts:img.news.ec.net.twEcNewsnews201905021556789902_60071.JPG"style="width:100%;height:100%;"
# 顧問公司也透漏，不少學員和員工都是受害者，如果學員上課受影響需要退費會幫忙處理，這回誆稱投資卻遭指控吸金大會，被害人只希望能盡快他們口中的王老師，能夠盡早面對。
# （封面圖／東森新聞）

# %%
#三立
import re
from bs4 import BeautifulSoup
r.encoding='utf-8'
soup=BeautifulSoup(r.text,'lxml') #以liml為解碼器
r=soup.find_all('p')
r='%s'*len(r) % tuple(r)
r=r.strip()
r1= re.compile(r'[<p> / br]')
r= r1.sub('' ,r )
r='%s'*len(r) % tuple(r)
r=r.split('<p style="margin-bottom' )[0]
r=r.strip()
r1= re.compile(r'[<p> / ahref="searchtagging2]')
r= r1.sub('' ,r )
print(r)
# Out:
# 一名從台灣返回日本l日本o日本o的女學生驗出感染新冠肺炎l新冠肺炎o新冠肺炎o病毒，因女學生就讀南部某大學，但中央流行疫情指揮中心未公布是哪所學校。被影射的高雄一所大學，學校表示並未接獲通知；但有學生在社群坦言沒錯，指朋友整班都被匡列，也在居家隔離中。
#
# 中央流行疫情指揮中心發言人莊人祥今天在防疫記者會指出，有關日本女學生個案，原本匡列15名接觸者居家隔離，但有兩生已不在國內，所以有13人需要居家隔離和採檢。昨天到現在已經採檢116位，有7人聯絡不到，目前有44人檢驗結果為陰性，剩下的7人預計晚上6點前檢驗出爐。
#
# 因中央流行疫情指揮中心只說明是「南部大學」，引起許多家長和學生疑慮，紛紛猜測到底是哪所學校？被盛傳的高雄一所大學，校方仍表示沒有接獲通知。不過卻有學生在社群討論，說沒錯就是這所，因為有朋友整班都被匡列，正在居家隔離中。
#
# 學生反映，真的是很好笑，同為學校學生，還得這樣用「猜」的？防疫這麼嚴重的事情未免太不公開透明。也有學生說，學校都是確定了才能給宣告，之前那一例也是確定之後才公告的，沒有作戲。

# %%
#ETToday
from bs4 import BeautifulSoup
r.encoding='utf-8'
soup=BeautifulSoup(r.text,'lxml') #以liml為解碼器
r=soup.find_all('p')
r='%s'*len(r) % tuple(r)
r=r.split('</p><p><span style="color' )[0]
r=r.strip()
r1= re.compile(r'[<p> /]')
r= r1.sub('' ,r )
print(r)
# Out:
# imgalt="▲▼《甘味》男星鐵板燒店打工求生（圖／翻攝自高盟傑臉書、YouTube）"height="450"src="cdn2.ettoday.netimages3359d3359576.jg"title="▲▼《甘味》男星鐵板燒店打工求生（圖／翻攝自高盟傑臉書、YouTube）"width="600"strong▲《甘味》男星驚爆販毒，遭收押禁見。（圖／翻攝自高盟傑臉書、YouTube）strong記者白珈陽／台中報導曾5度入圍金馬、金鐘獎，演藝事業前途看好的藝人高盟傑，卻連連爆出負面新聞，不但在2017年傳出欠債150萬元，甚至在拍攝《甘味人生》時跟劇組裡的每個人都借過一輪。沒想到，近日又傳出遭到台中地檢署緝毒小組查獲涉嫌販毒，檢方訊後也向法院聲請羈押禁見獲准，而日前他羈押期滿，檢方在向法院聲請續押獲准，全案目前正擴大偵辦中。高盟傑2017年被爆出欠許多藝人和身邊朋友債，就連隋棠也是債主之一，隋棠還為此在臉書溫馨喊話，「相信他有能力時便會還，而且人都有低谷和需要被幫助的時候」，而當時的高盟傑還曾上節目說明欠債始末，表示自己因為心軟幫忙朋友換票，卻遭背叛拿到芭樂票，好不容易紓困些許，又有朋友上門求救，讓他前後扛了百萬債務，只能一直向友人借錢補坑，自己也是受害者。風波一波未平一波又起，2019年3月又有一名身障女粉絲出面指控，高盟傑不斷向她借錢卻不還，另外替粉絲代收近500萬元的款項也私吞，之後人間蒸發，避不見面，而如今又被爆出涉嫌販毒遭到收押，處境相當難堪。據悉，高盟傑與同夥8月1日被台中地檢署查獲涉嫌販賣海洛因及安毒，檢方訊後認為他涉嫌重大，且牽涉許多人，案情也還需要深入調查，因此向法官聲請羈押禁見獲准。10月1日他羈押期屆滿2個月，檢方再度聲請續押獲准，全案將擴大偵辦中。

# %%
#CNA
from bs4 import BeautifulSoup
r.encoding='utf-8'
soup=BeautifulSoup(r.text,'lxml') #以liml為解碼器
r=soup.find_all('p')
r='%s'*len(r) % tuple(r)
r=r.split('電）' )[1].split('（編輯')[0]
r=r.strip()
r1= re.compile(r'[<p> /]')
r= r1.sub('' ,r )
print(r)
# Out:
# 高雄地方法院審理一件毒品走私案，誤認782公斤毒品為419公克，判處男子楊政錦4年徒刑定讞。檢察總長認為，原判決有罪刑不相當等違法之處，已向最高法院提起非常上訴。高雄檢警民國106年在澎湖縣目斗嶼附近查獲「新進滿貳號」漁船走私K他命原料鹽酸羥亞胺45包，經送刑事局檢驗後淨重為782公斤。檢警查出，全案是綽號「許利發」的男子委託楊政錦運送毒品，楊政錦再找張慶龍開漁船載運來台，兩人經雄檢起訴，一審判楊政錦4年，張慶龍5年10月。楊政錦放棄上訴，檢察官也未提上訴，刑期定讞。張慶龍不服上訴，二審法官才察覺一審判決誤載查扣毒品重量的烏龍，認為一審事實認定顯有重大違誤，改判處張慶龍有期徒刑11年，案經最高法院駁回上訴定讞。最高檢察署今天表示，高雄地檢署已於本月10日針對楊政錦部分聲請再審，最高檢察署也認為楊政錦案判決認定的犯罪事實與所採用的證據顯屬不符，又有罪刑不相當等違背法令之處，檢察總長江惠民14日核定提起非常上訴，已於昨天送達最高法院。

# %%
#NextMag
from bs4 import BeautifulSoup
r.encoding='utf-8'
soup=BeautifulSoup(r.text,'lxml') #以liml為解碼器
r=soup.find_all('p')
r='%s'*len(r) % tuple(r)
r=r.split('</span> </strong> </p><p></p><p>')[1].split('（撰文：' )[0]
r=r.strip()
r1= re.compile(r'[<p> /]')
r= r1.sub('' ,r )
print(r)
# Out:
# 2017年甫上線的推推房，將AI技術帶著房地產業，號稱運用人工智慧幫買家搜尋到最適合的物件，打破傳統利用大數據媒合系統震憾全市場，今年更是推行加密貨幣，以自家行號作為虛擬貨幣名稱-推推幣（TTT），但如今驚傳推推房創辦人林家豪疑似利用推推幣詐騙千萬，連台灣藝人周杰倫都慘遭捲入。《壹週刊》接獲爆料，推推房創辦人林家豪利用與周杰倫、及名詞曲創作人方文山的私交，找他們來替自己的公司拍攝推薦影片，林家豪更時不時在自己的IG、臉書o上與周杰倫夫婦等明星的合照。離譜的是，林家豪被控為了騙取投資人的資金，對外謊稱周杰倫是推推房投東，未來推推房所推行的推推幣，必會因周杰倫的名號而大漲，不少民眾聽到周杰倫三個字，紛紛掏錢出來，但推推幣一上交易所，立即跌停交易量根本近趨於0，嚇傻所有投資人。眼見投入資金血本無歸，投資人到處打探消息，這才曉得林家豪在去年9、10月間，利用推推幣吸了近200萬美金後，竟然無預警將公司員工全部資遣。資金到手反叫員工走路的異常舉動，讓不少投資人這才驚覺，推推�
p><p> </p><p><a href="https://s3-ap-northeast-1.amazonaws.com/lazybusiness/data/eccccccc_104/117636.jpg" target="_blank"><img alt="" src="https://s3-ap-northeast-1.amazonaws.com/lazybusiness/data/eccccccc_104/117636.jpg" style="width: 500px;"/></a></p><p> </p><p class="article__other-date"><i aria-hidden="true" class="fa fa-calendar"></i>2020-01-14</p><p class="article__other-date"><i aria-hidden="true" class="fa fa-calendar"></i>2020-01-20</p><p class="article__other-date"><i aria-hidden="true" class="fa fa-calendar"></i>2020-04-16</p><p class="article__other-date"><i aria-hidden="true" class="fa fa-calendar"></i>2020-05-21</p><p><i class="fa fa-phone" v=""></i>

# %%
#HK01
from bs4 import BeautifulSoup
r.encoding='utf-8'
soup=BeautifulSoup(r.text,'lxml') #以liml為解碼器
r=soup.find_all('p')
r='%s'*len(r) % tuple(r)
r=r.split('註冊')[1].split('案件編號')[0]
r=r.strip()
r1= re.compile(r'[<p> /] ')
r= r1.sub('' ,r )
print(r)
# Out:
# </p><class="wa4tvz-1 hMBiMl sc-gqjmRU jTjJUk" fontsizelevel="medium">5名年輕的台灣男子為到柬埔寨「免費旅行」，受人指使將冰毒及「k仔」纏在身上帶回台灣，卻在香港轉機時遭海關人員截獲，更發現該批毒品市值達591萬港元。5人今（11日）於高等法院各承認一項販毒罪，其中2人求情時稱本想臨陣退縮，卻被威嚇若不從要賠錢，或要脅會對其家人不利，其中一人更稱被恐嚇會「打爛你部車」，終未有勇氣退出。由於法官今仍有其他案件處理，把案押後至5月7日判刑。</p><class="e8xwya-0 hcByuh sc-gqjmRU hrgbln" fontsizelevel="medium">五名被告：李威辰（20歲）、陳彥廷（20歲）、鄭旭宏（24歲）、楊明軒（21歲）及翁尉翔（18歲）在高等法院承認販毒罪。（資料圖片）</p><class="s1v3m5dk-0 dnFOkZ sc-gqjmRU gBjLGB" fontsizelevel="medium">五名被告：李威辰（20歲）、陳彥廷（20歲）、鄭旭宏（24歲）、楊明軒（21歲）及翁尉翔（18歲），承認於2017年10月10日在香港國際機場販運9.81公斤固體冰毒及7.79公斤「k仔」。</p><class="s1v3m5dk-0 dnFOkZ sc-gqjmRU gBjLGB" fontsizelevel="medium"><strong class="rsxiiq-0 dljHPJ">被捕後認有人提供免費旅行</strong></p><class="s1v3m5dk-0 dnFOkZ sc-gqjmRU gBjLGB" fontsizelevel="medium">案情指，海關人員案發當日在機場先截獲李，並在其身上搜獲毒品，稍後時間再截獲其餘4人，並在5人身上搜出冰毒及「k仔」。5人在警誡下表示有人稱向他們提供「免費旅行」及一些金錢，故幫忙帶毒品回台灣，其中有人直認為錢鋌而走險，但亦有人表示查欲臨陣退縮，但受威脅參與販毒。</p><class="s1v3m5dk-0 dnFOkZ sc-gqjmRU gBjLGB" fontsizelevel="medium"><strong class="rsxiiq-0 dljHPJ">沒有勇氣退出</strong></p><class="s1v3m5dk-0 dnFOkZ sc-gqjmRU gBjLGB" fontsizelevel="medium">辯方求情指，鄭由朋友介紹下得知此「免費旅行」，答應後卻感到不妥，一度想退出，但接洽人�
嚴重傷亡，許多人甚至因此在黑暗中不慎墜崖、落入河中。除了包括巴布在內的3名官兵當場陣亡，後來撤回後方的17名傷兵，因為在高海拔地區落入冰冷河水，最後也失溫不治。總的來說，比哈爾團第16營是遭到襲擊，而且據印媒說法，完全是赤手空拳對上解放軍的鐵棒、木棍、石塊等兵器，而且撤退時還被追擊，多人墜入河谷。</p><aid="71">此外，一份疑似由現場解放軍撰寫的事發經過近日在中國網站熱傳，或可作為兩軍對陣細節的參考。這份資料顯示，巴布15日下午帶一隊人馬越線到中方施工工地交涉，理由是「在該地點施工違反了脫離接觸的共識」，中方一開始不予理睬。期間印軍在對峙交涉時與裝備狼牙棒的解放軍工兵部隊發生衝突，巴布上校受重傷（疑似被兵工鏟擊破頭部）被緊急送回，其餘印軍士兵被中方控制。</p><aid="72">當天傍晚傳出巴布身亡，印軍一名少校帶著一大批手持棍棒的士兵又來到中方施工點，打傷中方2名施工人員。中方大部隊200餘人攜帶鐵棒、伸縮棍、盾牌、鐵鍬兵工鏟趕來助陣，雙方爆發激烈衝突。由於裝備、人數和士氣相比懸殊，造成印軍死傷嚴重。印軍潰逃後，中方在高處向他們丟擲石塊，印軍多人墜落谷中。中方旅長下令停止衝突後，以陸航直升機接走傷員，印軍則摸黑以人力順著加勒萬河下游搜尋傷員，其餘人在海拔五千公尺的嚴寒高原徒步走回營地，最後才會傳出凍死17人。</p><aid="73"><iframe allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen="" frameborder="0" height="394" src="https://www.youtube.com/embed/jhYvc81NFWE" width="700"></iframe></p><id="author_contents_title">最近三則報導</p><class="donation_label_text">

# %% [markdown]
# ## 調校區

# %%
#On.cc
from bs4 import BeautifulSoup
r.encoding='utf-8'
soup=BeautifulSoup(r.text,'lxml') #以liml為解碼器
r=soup.find_all('p')
r='%s'*len(r) % tuple(r)
r=r.strip()
r1= re.compile(r'[<p> / br] ')
r= r1.sub('' ,r )
print(r)
# Out:
# <class="summary">
# 	各地政府聯手打擊本港黑幫和勝和前坐館泰國大毒梟「上海仔」郭永鴻的販毒集團，令毒販趁「末日」前瘋狂出貨。越南警方周六（20日）公布在胡志明市破獲一宗世紀毒案，檢獲1.1噸冰毒及約1噸氯胺酮（俗稱K仔），共值7.42億港元。警方指毒品從泰國運入越南境內，行動中拘捕兩名台灣籍男子及一名越南人。今次是越南一周內破獲第3宗與上海仔集團有關的毒案。<br/><br/>當地傳媒報道，胡志明市警方日前發現兩輛貨車停在路邊，疑似轉移貨物，形迹可疑，遂上前截查。警員檢查期間，兩名台籍男子突然開車欲逃走，遭警方當場截下及拘捕。兩人分別為33歲的葉清偉（Yeh Ching Wei，音譯）和31歲的姜維池（Chiang Wei Chih，音譯）。警方在貨車內檢獲60個揚聲器，每個內藏10包偽裝成茶葉包的冰毒，共有600包，總重約600公斤。<br/><br/>警方循貨車行駛路線深入調查，追蹤到另兩個地點，分別發現大批毒品，當中在43個揚聲器內，再搜獲共逾500公斤的冰毒，案中檢獲冰毒共值4.84億港元。警方亦拘捕一名越南籍男子，在其住處起出約1000公斤的K仔，總值2.58億港元。<br/><br/>警方指出，所有毒品均是來自泰國。葉清偉是首次入境越南，姜維池則是自去年以來第3次來到越南。他們供稱，是在一名中國籍疑犯指使下，將毒品由同奈省運到胡志明市。警方目前正擴大調查，釐清上述案件與本月17日在義安省破獲的毒案是否有關聯。<br/><br/>今次是過去166日內第30宗涉及中國大陸、台灣、泰國、緬甸、澳洲、日本、菲律賓、越南及馬來西亞的毒品案，全部均涉及上海仔販毒集團。由於警方禁毒力度不斷加強，導致一條龍由設廠生產到販賣毒品的上海仔販毒集團急於尋找出貨渠道，將在金三角生產的毒品運往海外。但近期接連破獲多宗特大毒品案，令上海仔已被國際禁毒組織盯上，其軍方及警察保護傘已失效。<br/><br/>雖然上海仔因獲警方及律政司兩把保護傘包庇，每次在香港警方執法前均可聞風先遁；但據知大陸早已部署針對跨境犯罪的大規模掃黑行動。分析指，大陸政法高層高調督導打黑，湖南、廣東等地執法機構也不敢怠慢，不斷加強打擊犯罪分子的保護傘，令上海仔四面楚歌。<br/><br/>上海仔自從在本港棄保潛逃後，流竄至泰國、柬埔寨、越南及瑞士，上述國家因與香港仍無引渡協定，故他刻意逃往以迴避追緝。<br/><br/>上海仔借病潛逃 ﹕http://hk.on.cc/fea/shanghai/
# 						</p>

# %%
#爬文第一步&讓網站以為你是真人(User-agent的輸入)
import requests
from requests.packages import urllib3
urllib3.disable_warnings()
headers={
    'User-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36'
}
r=requests.get('https://news.tvbs.com.tw/politics/1175419',verify=False,headers=headers)

# %%
import re
from bs4 import BeautifulSoup
r.encoding='utf-8'
soup=BeautifulSoup(r.text,'lxml') #以liml為解碼器
r=soup.find_all('p')
r='%s'*len(r) % tuple(r)
r=r.split('>大<')[1]
r=r.strip()
r1= re.compile(r'[<p> / br]')
r= r1.sub('' ,r )
print(r)
# Out:
# 苗栗縣銅鑼鄉長李瑞廷被控競選期間，透過競選總部執行長以每戶新台幣3000元行賄買票，經落選對手提出當選無效之訴，苗栗地院今天宣判李瑞廷當選無效。李瑞廷將提出上訴。苗栗地方法院今天發布新聞稿指出，107年11月24日第18屆銅鑼鄉長選舉，李瑞廷獲5668票，經苗栗縣選委會公告當選；落選人謝昌年則主張，李瑞廷競選團隊曾姓執行長於投票日前，涉嫌替李賄選買票，對李瑞廷提起當選無效之訴。合議庭審理後，判決李瑞廷當選無效。

# %%
#取內容
#由於試探會把所有的p內容蒐羅，整成一個list，每段一個位置
#以下將一個list的內容統合成一串字串
import re
content='%s'*len(article) % tuple(article)  
content1=content.strip()
content2= re.compile(r'[<p> /]')
content3= content2.sub('' , content1)
print(content3)
# Out:
# divclass="tabsParent"divdivid="fb-root"divdivclass="ageLimitDialog"
# divclass="ageLimiteBox"
# h2style="text-align:center;"strong警告：未滿十八歲不得觀賞瀏覽strongh2
# style="text-align:center;"您是否已經年滿18歲？
# divclass="rating_btn_Blk"
# buttonclass="isYes"是button
# ahref=""buttonclass="isNo"否buttona
# div
# div
# divdivclass="ageLimiteBox"
# h2style="text-align:center;"strong警告：未滿十八歲不得觀賞瀏覽strongh2
# style="text-align:center;"您是否已經年滿18歲？
# divclass="rating_btn_Blk"
# buttonclass="isYes"是button
# ahref=""buttonclass="isNo"否buttona
# div
# divdivclass="rating_btn_Blk"
# buttonclass="isYes"是button
# ahref=""buttonclass="isNo"否buttona
# divdivclass="newDetailContainer"data-agerestriction="false"
# divclass="newDetailBox"
# divclass="to_banner_titlemargin20"
# class="fast_title"即時快訊
# !--快訊轮播--
# divclass="nowmsg-container"id="banner1"
# ulclass="twoNewsswier-wraer"
# ul
# div
# sanclass="title_san_first"san
# divclass="nowmsg-container"id="banner2"
# ulclass="twoNewsswier-wraer"
# ul
# div
# div
# !--adname:age-to--
# divclass="adwad-age-to"div
# !--果實廣告,adname:fruit-1--
# divclass="adwad-fruit-1"div
# divclass="breadCrumbs"
# !--面包屑导航--
# ahref="htts:www.nownews.com"NOWnews今日新聞a
# &gt;ahref="catolitics"政治a
# div
# !--dable隱藏模組,adname:dable-hidden--
# divclass="hidedableadwad-dable-hidden"div
# !--結束Dableresonsive如有任何疑問，請瀏覽htt:dable.io--
# divclass="newsContainer"
# h3class="newsTitle"馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識h3
# divclass="newsInfo"記者吳承翰台北報導-2020-06-2107:56:39div
# divclass="newsBox"
# !--新聞左側區域--
# divclass="newsContainerLeft"
# divclass="shareBox"
# !--facebook--
# divclass="share-button"data-href="htts:www.facebook.comsharer.h?u=htts:www.nownews.comnewsolitics5022784"
# imgalt=""src="imagesfacebook.ng"srcset=""div
# !--微博--
# divclass="share-button"data-href="htt:service.weibo.comshareshare.h?url=htts:www.nownews.comnewsolitics5022784&am;title=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識&am;language=zh_tw"
# imgalt=""src="imagesweibo.ng"srcset=""div
# !--推特--
# divclass="share-button"data-href="htts:twitter.comintenttweet?text=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識&am;url=htts:www.nownews.comnewsolitics5022784&am;via=NOWnews今日新聞"
# imgalt=""src="imagestwitter.ng"srcset=""div
# !--linea--
# divclass="share-button"data-href="htts:line.meRmsgtext?馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識%0D%0Ahtts:www.nownews.comnewsolitics5022784"
# imgalt=""src="imagesline.ng"srcset=""div
# !--telegram--
# divclass="share-button"data-href="htts:telegram.meshareurl?url=htts:www.nownews.comnewsolitics5022784&am;text=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識"
# imgalt=""src="imagestelegram.ng"srcset=""div
# !--领英--
# divclass="share-button"data-href="htts:www.linkedin.comshareArticle?mini=true&am;url=htts:www.nownews.comnewsolitics5022784&am;title=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識"
# imgalt=""src="imageslinkedin.ng"srcset=""div
# !--邮箱--
# divclass="share-button"data-href="mailto:?subject=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識&am;body=htts:www.nownews.comnewsolitics5022784"
# imgalt=""src="imagesemail.ng"srcset=""div
# !--打印--
# divclass="rint"data-href="#"imgalt=""src="imagesrint.ng"srcset=""div
# div
# divclass="newsImg"
# imgalt=""src="htts:media.nownews.comnn_mediathumbnail2020061592697327718-7b69e037866f42e2862d2644c181fea8-800x370.jg?unShow=false"
# divclass="imgTitle"▲前國民黨主席朱立倫。(圖記者吳承翰攝)div
# div
# divclass="fontSizeChange"
# divclass="fontSizeSmall"fontsize="15"小div
# liaadkey="74"href="htts:www.nownews.comcatfinancefund-investment"投資從小額開始！找不到標的、不會投資都看這ali
# liahref="newsolitics5021237"用二備金宣傳台北大縱走挨批　黃珊珊酸：馬郝時代花更多ali
# liid="_oIn_recommend_word"li
# ul
# div
# div
# !--NOW民調調查局--
# divclass="bureauInvestigation"
# divclass="biLabel"NOW民調中心div
# divclass="biList"
# ul
# li
# aclass="biTo"href="htts:vote.nownews.comanswer4028818a72cbf2130172d0968039176flogin"
# div
# imgdata-original="htts:vote.nownews.comimagesquestion4028818a72cbf2130172d0968039176fimg"src="htts:vote.nownews.comimagesquestion4028818a72cbf2130172d0968039176fimg"
# div
# class="biTitle"您怎麼看這次的監察院風波？
# a
# divclass="biBottom"
# divclass="radioBox"
# labelinutname="item0"tye="radio"value=""sansan贊成，陳菊相當適任。label
# labelinutname="item0"tye="radio"value=""sansan不贊成，監察院長應該由超黨派人選出任。label
# labelinutname="item0"tye="radio"value=""sansan沒意見。label
# div
# divclass="continueAnswer"ahref="htts:vote.nownews.comanswer4028818a72cbf2130172d0968039176flogin"繼續作答adiv
# div
# li
# li
# aclass="biTo"href="htts:vote.nownews.comanswer4028818a725dcf460172c65537b1264elogin"
# div
# imgdata-original="htts:vote.nownews.comimagesquestion4028818a725dcf460172c65537b1264eimg"src="htts:vote.nownews.comimagesquestion4028818a725dcf460172c65537b1264eimg"
# div
# class="biTitle"炎炎夏日來臨！哪首南韓女團的夏季作品最讓你聽不膩？
# a
# divclass="biBottom"
# divclass="radioBox"
# labelinutname="item1"tye="radio"value=""sansan少女時代《Party》label
# labelinutname="item1"tye="radio"value=""sansanSISTAR《TOUCHMYBODY》label
# labelinutname="item1"tye="radio"value=""sansanf(x)《HOTSUMMER》label
# div
# divclass="continueAnswer"ahref="htts:vote.nownews.comanswer4028818a725dcf460172c65537b1264elogin"繼續作答adiv
# div
# li
# li
# aclass="biTo"href="htts:vote.nownews.comanswer4028818a725dcf460172b69665dc3347login"
# div
# imgdata-original="htts:vote.nownews.comimagesquestion4028818a725dcf460172b69665dc3347img"src="htts:vote.nownews.comimagesquestion4028818a725dcf460172b69665dc3347img"
# div
# class="biTitle"[抽獎]端午粽子大戰！您覺得今年哪種粽會最受歡迎？
# a
# divclass="biBottom"
# divclass="radioBox"
# labelinutname="item2"tye="radio"value=""sansan南部粽label
# labelinutname="item2"tye="radio"value=""sansan北部粽label
# labelinutname="item2"tye="radio"value=""sansan鹼粽label
# div
# divclass="continueAnswer"ahref="htts:vote.nownews.comanswer4028818a725dcf460172b69665dc3347login"繼續作答adiv
# div
# li
# ul
# scrit
# (function(d,a,b,l,e,_){
# if(d[b]&&d[b].q)return;
# d[b]=function(){
# (d[b].q=d[b].q||[]).ush(arguments)
# };
# e=a.createElement(l);
# e.async=1;
# e.charset='utf-8';
# e.src='static.dable.iodistlugin.min.js?v=20200620015227';
# _=a.getElementsByTagName(l)[0];
# _.arentNode.insertBefore(e,_);
# })(window,document,'dable','scrit');
# scrit
# div
# div
# divclass="wantviewMore"
# divclass="wantviewMoreLabel"想看更多div
# !--消息轮播--
# divclass="wantViewMore-container"id="wantViewMore"
# divclass="swier-wraer"
# divclass="swier-slide"
# aadkey="82"href="htts:bit.ly3ftvyJV"divclass="wantViewMoreImg"imgalt=""src="htts:ad2018.nownews.comstorageimag
divclass="wantViewMoreImg"imgalt=""src="htts:ad2018.nownews.comstorageimagesyJrXUy86WI4JYnKa76iOBtKEoffKn9nAz1WoM1Gz.jeg"div在家工作快被主子逼瘋？男子一招神技解決：把貓咪「收納」a
# aadkey="97"href="htts:lay.nownews.comarchives331227"divclass="wantViewMoreImg"imgalt=""src="htts:ad2018.nownews.comstorageimages4C8W18uKVySUXaktsliP0JYu3i9uL4Zr1k724lXy.ng"div華泰王子大飯店九華樓X驢子餐廳料理中西軍母親節外帶限定a
# aadkey="98"href="htts:bit.ly2ZFfHmI"divclass="wantViewMoreImg"imgalt=""src="htts:ad2018.nownews.comstorageimagesqScAK3QI5FlImI6ThXQicn53oA98L6T3TB5cEgT.jeg"div61口罩禁令解除！自由販售價格恐高於實名制，該怎麼買一次看清楚！a
# aadkey="99"href="htts:bit.ly2YKA2VE"divclass="wantViewMoreImg"imgalt=""src="htts:ad2018.nownews.comstorageimagesMXfAPZMK0qtWKDsn9mgfcFiZi7QQx1jiVYimwmIs.jeg"div美國八個神秘懸案多年未解至今仍然讓人匪夷所思a
# aadkey="100"href="htts:www.nownews.comnews5007455"divclass="wantViewMoreImg"imgalt=""src="htts:ad2018.nownews.comstorageimagesMtouFtQkG8sZO2BFoWiGjAdnPUUoOVbY7UXGSgu.jeg"div沒在跟你開玩笑！《瘋種菜》不只送「真蔬菜」還送黃金a
# div
# div
# divclass="swier-agination"div!--分页器。如果放置在swier-container外面，需要自定义样式。--
# div
# scrit
# varwantViewMoreSwier=newSwier('#wantViewMore',{
# autolay:6000,
# saceBetween:10,
# agination:{
# el:'.swier-agination',
# clickable:true,
# },
# loo:true
# });
# 鼠标移入停止自动播放
# document.getElementById("wantViewMore").onmouseover=function(){
# wantViewMoreSwier.stoAutolay()
# };
# document.getElementById("wantViewMore").onmouseout=function(){
# wantViewMoreSwier.startAutolay()
# };
# scrit
# div
# !--dable猜你喜歡--
# divclass="guessYouLikeadwad-dable-guessyoulike"div
# divclass="faceBookNote"
# divclass="fb-like"data-action="like"data-href="htts:www.nownews.comnewsolitics5022784"data-layout="button_count"data-share="true"data-show-faces="false"data-size="large"div
# divclass="fb-save"data-size="large"data-uri="htts:www.nownews.comnewsolitics5022784"div
# divclass="fb-comments"data-href="htts:www.nownews.comnewsolitics5022784"data-numosts="5"div
# div
# divclass="shareBox"
# !--facebook--
# divclass="share-button"data-href="htts:www.facebook.comsharer.h?u=htts:www.nownews.comnewsolitics5022784"
# imgalt=""src="imagesfacebook.ng"srcset=""div
# !--微博--
# divclass="share-button"data-href="htt:service.weibo.comshareshare.h?url=htts:www.nownews.comnewsolitics5022784&am;title=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識&am;language=zh_tw"
# imgalt=""src="imagesweibo.ng"srcset=""div
# !--推特--
# divclass="share-button"data-href="htts:twitter.comintenttweet?text=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識&am;url=htts:www.nownews.comnewsolitics5022784&am;via=NOWnews今日新聞"
# imgalt=""src="imagestwitter.ng"srcset=""div
# !--linea--
# divclass="share-button"data-href="htts:line.meRmsgtext?馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識%0D%0Ahtts:www.nownews.comnewsolitics5022784"
# imgalt=""src="imagesline.ng"srcset=""div
# !--telegram--
# divclass="share-button"data-href="htts:telegram.meshareurl?url=htts:www.nownews.comnewsolitics5022784&am;text=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識"
# imgalt=""src="imagestelegram.ng"srcset=""div
# !--领英--
# divclass="share-button"data-href="htts:www.linkedin.comshareArticle?mini=true&am;url=htts:www.nownews.comnewsolitics5022784&am;title=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識"
# imgalt=""src="imageslinkedin.ng"srcset=""div
# !--邮箱--
# divclass="share-button"data-href="mailto:?subject=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識&am;body=htts:www.nownews.comnewsolitics5022784"
# imgalt=""src="imagesemail.ng"srcset=""div
# !--打印--
# divclass="rint"data-href="#"imgalt=""src="imagesrint.ng"srcset=""div
# div
# !--網友看什麼,adname:eole-seen--
# divclass="friendWatchWhatadwad-eole-seen"div
# div
# !--新聞右側區域--
# divclass="newsContainerRight"
# !--右侧第一则广告--
# divclass="adadone"
# !--Nownews_olitical_article_300x250_RT_new2--
# divid="div-gt-ad-1497253737557-0"style="height:250x;width:300x;"val="'5799246Nownews_olitical_article_300x250_RT_new2',[300,250],'div-gt-ad-1497253737557-0'"
# scrit
# googletag.cmd.ush(function(){
# googletag.defineSlot('5799246Nownews_olitical_article_300x250_RT_new2',[300,250],'div-gt-ad-1497253737557-0').addService(googletag.ubads());
# googletag.ubads().enableSingleRequest();
# googletag.ubads().collaseEmtyDivs(true);
# googletag.enableServices();
# });
# googletag.cmd.ush(function(){googletag.dislay('div-gt-ad-1497253737557-0');});
# scrit
# div
# div
# !--即时模块--
# divclass="immediate"
# divclass="immTitle"
# imgalt=""src="imagesxiaoxi.ng"srcset=""
# san即時san
# div
# ul
# ul
# div
# !--右侧第二则广告--
# divclass="adadThree"
# !--Nownews_olitical_article_300x250_RM_new2--
# divid="div-gt-ad-1497253763874-0"style="height:250x;width:300x;"val="'5799246Nownews_olitical_article_300x250_RM_new2',[300,250],'div-gt-ad-1497253763874-0'"
# scrit
# googletag.cmd.ush(function(){
# googletag.defineSlot('5799246Nownews_olitical_article_300x250_RM_new2',[300,250],'div-gt-ad-1497253763874-0').addService(googletag.ubads());
# googletag.ubads().enableSingleRequest();
# googletag.ubads().collaseEmtyDivs(true);
# googletag.enableServices();
# });
# googletag.cmd.ush(function(){googletag.dislay('div-gt-ad-1497253763874-0');});
# scrit
# div
# div
# !--社群连接--
# divclass="grouConcat"
# divclass="gcFacebook"
# ahref="htts:www.facebook.comnownews"target="_blank"
# imgalt=""src="imagesfacebookIcon.ng"srcset=""
# san追蹤san
# a
# div
# divclass="gcToutube"
# ahref="htts:www.youtube.comchannelUCg8EwsqYmiw7G267xxPyXsg"target="_blank"
# imgalt=""src="imagesyoutube.ng"srcset=""san訂閱san
# a
# div
# divclass="gcIg"
# ahref="htts:www.instagram.comnownews"target="_blank"
# imgalt=""src="imagesins.ng"srcset=""san追蹤san
# a
# div
# div
# divclass="faceBookPage"
# iframeallow="encryted-media"allowtransarency="true"frameborder="0"height="500"scrolling="no"src="htts:www.facebook.comluginsage.h?href=htts%3A%2F%2Fwww.facebook.com%2Fnownews%2F&am;tabs=timeline&am;width=340&am;height=500&am;small_header=false&am;adat_container_width=true&am;hide_cover=false&am;show_faceile=true&am;aId=297786081079959&am;locale=zh_TW"style="border:none;overflow:hidden"width="340"iframe
# div
# !--關鍵字廣告,adname:keyword--
# divclass="adwad-right-keyword"div
# !--右侧第三则广告--
# divclass="adadFour"
# !--Nownews_olitical_article_300x250_RB_new2--
# divid="div-gt-ad-1497253791714-0"style="width:300x;"val="'5799246Nownews_olitical_article_300x250_RB_new2',[300,250],'div-gt-ad-1497253791714-0'"
# scrit
# googletag.cmd.ush(function(){
# googletag.defineSlot('5799246Nownews_olitical_article_300x250_RB_new2',[300,250],'div-gt-ad-1497253791714-0').addService(googletag.ubads());
# googletag.ubads().enableSingleRequest();
# googletag.ubads().collaseEmtyDivs(true);
# googletag.enableServices();
# });
# googletag.cmd.ush(function(){googletag.dislay('div-gt-ad-1497253791714-0');});
# scrit
# div
# div
# !--右侧第四则广告--
# divclass="adadFour"
# div
# !--推荐阅读--
# divclass="recommendRead"style=""
# divclass="closeRecommendReadBtn"imgalt=""src="imagesclose_recommend.jg"srcset=""
# div
# divclass="recommendReadTitle"推薦閱讀div
# ul
# li
# aadkey="47"href="htts:bit.ly2XqyDDc"
# 糖友選擇適當營養補充品　外食族控醣好幫手
# div
# imgalt="糖友選擇適當營養補充品　外食族控醣好幫手"src="htts:ad2018.nownews.comstorageimages821l3Db9erCYqouMMF2LXa2uWY5OiZBQxzoP3YWL.jeg"
# div
# a
# li
# li
# aadkey="48"href="htts:www.nownews.comnews5020763"
# 大學生該買「筆電」vs.「機車」　這款旗艦車終結論戰！
# div
# imgalt="大學生該買「筆電」vs.「機車」　這款旗艦車終結論戰！"src="htts:ad2018.nownews.comstorageimagesmRKUqBkh6Bm0ETEMR9ucazEm4tMiQnTMGcdys9I0.jeg"
# div
# a
# li
# li
# ahref="newsolitics4042224"
# 蘇貞昌宣布「已經在發現金了！」受惠對象下周請看存簿
# div
# imgalt="蘇貞昌宣布「已經在發現金了！」受惠對象下周請看存簿"src="htts:media.nownews.comnn_mediathumbnail2020031585275004-154ab3153a7237b3689ca88d66745014-800x600.jg"
# div
# a
# li
# li
# ahref="newsolitics3242595"
# 負債3千億兩個月還7百億？高雄真實債務曝光！網友全酸爆
# div
# imgalt="負債3千億兩個月還7百億？高雄真實債務曝光！網友全酸爆"src="htts:media.nownews.comnn_mediathumbnail2019021551067794-107095441962443bcd48bba95fb8c4f6-696x485.ng"
# div
# a
# li
# li
# ahref="newsolitics3025391"
# 擔心慘輸韓國瑜？陳其邁：我沒選上「會影響全台灣」
# div
# imgalt="擔心慘輸韓國瑜？陳其邁：我沒選上「會影響全台灣」"src="htts:media.nownews.comnn_mediathumbnail2018101540038592-3bc25e3ec7ee3135692b26d44efcae8b-696x391.jg"
# div
# a
# li
# ul
# div
# div
# div
# div
# div
# divdivclass="newDetailBox"
# divclass="to_banner_titlemargin20"
# class="fast_title"即時快訊
# !--快訊轮播--
# divclass="nowmsg-container"id="banner1"
# ulclass="twoNewsswier-wraer"
# ul
# div
# sanclass="title_san_first"san
# divclass="nowmsg-container"id="banner2"
# ulclass="twoNewsswier-wraer"
# ul
# div
# div
# !--adname:age-to--
# divclass="adwad-age-to"div
# !--果實廣告,adname:fruit-1--
# divclass="adwad-fruit-1"div
# divclass="breadCrumbs"
# !--面包屑导航--
# ahref="htts:www.nownews.com"NOWnews今日新聞a
# &gt;ahref="catolitics"政治a
# div
# !--dable隱藏模組,adname:dable-hidden--
# divclass="hidedableadwad-dable-hidden"div
# !--結束Dableresonsive如有任何疑問，請瀏覽htt:dable.io--
# divclass="newsContainer"
# h3class="newsTitle"馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識h3
# divclass="newsInfo"記者吳承翰台北報導-2020-06-2107:56:39div
# divclass="newsBox"
# !--新聞左側區域--
# divclass="newsContainerLeft"
# divclass="shareBox"
# !--facebook--
# divclass="share-button"data-href="htts:www.facebook.comsharer.h?u=htts:www.nownews.comnewsolitics5022784"
# imgalt=""src="imagesfacebook.ng"srcset=""div
# !--微博--
# divclass="share-button"data-href="htt:service.weibo.comshareshare.h?url=htts:www.nownews.comnewsolitics5022784&am;title=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識&am;language=zh_tw"
# imgalt=""src="imagesweibo.ng"srcset=""div
# !--推特--
# divclass="share-button"data-href="htts:twitter.comintenttweet?text=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識&am;url=htts:www.nownews.comnewsolitics5022784&am;via=NOWnews今日新聞"
# imgalt=""src="imagestwitter.ng"srcset=""div
# !--linea--
# divclass="share-button"data-href="htts:line.meRmsgtext?馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識%0D%0Ahtts:www.nownews.comnewsolitics5022784"
# imgalt=""src="imagesline.ng"srcset=""div
# !--telegram--
# divclass="share-button"data-href="htts:telegram.meshareurl?url=htts:www.nownews.comnewsolitics5022784&am;text=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識"
# imgalt=""src="imagestelegram.ng"srcset=""div
# !--领英--
# divclass="share-button"data-href="htts:www.linkedin.comshareArticle?mini=true&am;url=htts:www.nownews.comnewsolitics5022784&am;title=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識"
# imgalt=""src="imageslinkedin.ng"srcset=""div
# !--邮箱--
# divclass="share-button"data-href="mailto:?subject=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識&am;body=htts:www.nownews.comnewsolitics5022784"
# imgalt=""src="imagesemail.ng"srcset=""div
# !--打印--
# divclass="rint"data-href="#"imgalt=""src="imagesrint.ng"srcset=""div
# div
# divclass="newsImg"
# imgalt=""src="htts:media.nownews.comnn_mediathumbnail2020061592697327718-7b69e037866f42e2862d2644c181fea8-800x370.jg?unShow=false"
# divclass="imgTitle"▲前國民黨主席朱立倫。(圖記者吳承翰攝)div
# div
# divclass="fontSizeChange"
# divclass="fontSizeSmall"fontsize="15"小div
# divclass="fontSizeMidactive"fontsize="17"中div
# divclass="fontSizeLarge"fontsize="19"大div
# div
# divclass="newsMsg"itemro="articleBody"
# 國民黨主席江啟臣日前宣布改革委員會討論成果，兩岸論述方面提sanstyle="background-color:rgb(255,255,255);color:rgb(34,34,34);"四大支柱，表明「九二共識是sansanstyle="background-color:rgb(255,255,255);color:rgb(59,59,59);"『過去』扮演兩岸求同存異的重要工具sansanstyle="background-color:rgb(255,255,255);color:rgb(34,34,34);"」。傳出此論述引起前總統馬英九、前副總統吳敦義的不滿，原先江邀請前黨主席們餐敘、共商改革及高雄補選，馬、吳san「因故」不便出席。21日朱立倫被問及此議題，他表示相關論述，還是要等到大家聚在一起時才好討論。brbr傳出黨中央憂心改革引起反彈，對於改革委員會的「建議」，仍要聽取基層意見，才會送交全代會通過，江啟臣也邀請歷任國民黨主席23日在黨秘書長李乾龍家餐敘、共商改革及高雄市長補選大計。brbr但在江啟臣發表九二共識是過去式的談話後，原先答應出席的馬英九、吳敦義改變立場，皆「因故」不出席餐敘，等同於不幫江啟臣背書。也曾在國民黨敗選後接下黨主席、前新北市長朱立倫說「我想黨的改革是很努力，大家可以多提供一些不同意見，最後再來凝聚共識，這段時間江主席很辛苦，大家多給改革委員會一些鼓勵吧。」brbr而對於馬英九、吳敦義皆堅持九二共識是國民黨兩岸論述的基礎，朱立倫說「這個我們目前因為還沒一起聚會，聚會在討論。」媒體問及在馬、吳皆不出席餐敘的情況下，他是否會赴約？朱立倫說「因為這個安排主要針對於高雄輔選，不管有沒有吃飯大家都會全力以赴討論高雄市補選。」brbr
#
# div
# !--其他人正在看--
# divclass="othersPeoleLookadwad-dable-watching"div
# !--文內廣告,adname:article-inside--
# divclass="adwad-article-inside"div
# !--影片廣告truvidorviewdeos--
# divclass="truvidadwad-video-mixin"data-category="olitics"div
# divclass="keywordBox"
# divclass="keywordLabel"NOWnews關鍵字div
# divclass="keyWordContent"
# div
# ahref="tag.html?name=zN5DBrLD9X"朱立倫a
# div
# div
# ahref="tag.html?name=QKw8gaKo2q"馬英九a
# div
# div
# ahref="tag.html?name=V1e7wnoZy"九二共識a
# div
# div
# ahref="tag.html?name=OlQ8LjVoe5"江啟臣a
# div
# div
# ahref="tag.html?name=LGoYElxbom"吳敦樣a
# div
# div
# div
# !--果實廣告,adname:fruit-2--
# divclass="adwad-fruit-2"div
# divclass="extendRead"
# divclass="readLabel"延伸閱讀div
# divclass="readList"
# ul
# liahref="htts:www.nownews.comnewsolitics5022209"再見了九二共識！江啟臣澄清：國民黨絕非「小綠」ali
# liahref="htts:www.nownews.comnewsolitics5022029"黃健庭接監院　江啟臣：遺憾！相信不至於出現「跳船潮」ali
# liaadkey="73"href="htts:bit.ly3hyAa3h"投資人莫慌！後疫情時代怎投資　AI「存基金」鎖定雙技美ali
# liahref="htts:www.nownews.comnewsolitics5021433"江啟臣宣布黨產歸零！全捐公務員和勞工退休基金兼做公益ali
# ul
# ul
# liahref="newsolitics5021305"二備金拍宣傳片黃珊珊扯馬郝　游淑慧嗆：別學柯文哲賴皮ali
# liaadkey="74"href="htts:www.nownews.comcatfinancefund-investment"投資從小額開始！找不到標的、不會投資都看這ali
# liahref="newsolitics5021237"用二備金宣傳台北大縱走挨批　黃珊珊酸：馬郝時代花更多ali
# liid="_oIn_recommend_word"li
# ul
# div
# div
# !--NOW民調調查局--
# divclass="bureauInvestigation"
# divclass="biLabel"NOW民調中心div
# divclass="biList"
# ul
# li
# aclass="biTo"href="htts:vote.nownews.comanswer4028818a72cbf2130172d0968039176flogin"
# div
# imgdata-original="htts:vote.nownews.comimagesquestion4028818a72cbf2130172d0968039176fimg"src="htts:vote.nownews.comimagesquestion4028818a72cbf2130172d0968039176fimg"
# div
# class="biTitle"您怎麼看這次的監察院風波？
# a
# divclass="biBottom"
# divclass="radioBox"
# labelinutname="item0"tye="radio"value=""sansan贊成，陳菊相當適任。label
# labelinutname="item0"tye="radio"value=""sansan不贊成，監察院長應該由超黨派人選出任。label
# labelinutname="item0"tye="radio"value=""sansan沒意見。label
# div
# divclass="continueAnswer"ahref="htts:vote.nownews.comanswer4028818a72cbf2130172d0968039176flogin"繼續作答adiv
# div
# li
# li
# aclass="biTo"href="htts:vote.nownews.comanswer4028818a725dcf460172c65537b1264elogin"
# div
# imgdata-original="htts:vote.nownews.comimagesquestion4028818a725dcf460172c65537b1264eimg"src="htts:vote.nownews.comimagesquestion4028818a725dcf460172c65537b1264eimg"
# div
# class="biTitle"炎炎夏日來臨！哪首南韓女團的夏季作品最讓你聽不膩？
# a
# divclass="biBottom"
# divclass="radioBox"
# labelinutname="item1"tye="radio"value=""sansan少女時代《Party》label
# labelinutname="item1"tye="radio"value=""sansanSISTAR《TOUCHMYBODY》label
# labelinutname="item1"tye="radio"value=""sansanf(x)《HOTSUMMER》label
# div
# divclass="continueAnswer"ahref="htts:vote.nownews.comanswer4028818a725dcf460172c65537b1264elogin"繼續作答adiv
# div
# li
# li
# aclass="biTo"href="htts:vote.nownews.comanswer4028818a725dcf460172b69665dc3347login"
# div
# imgdata-original="htts:vote.nownews.comimagesquestion4028818a725dcf460172b69665dc3347img"src="htts:vote.nownews.comimagesquestion4028818a725dcf460172b69665dc3347img"
# div
# class="biTitle"[抽獎]端午粽子大戰！您覺得今年哪種粽會最受歡迎？
# a
# divclass="biBottom"
# divclass="radioBox"
# labelinutname="item2"tye="radio"value=""sansan南部粽label
# labelinutname="item2"tye="radio"value=""sansan北部粽label
# labelinutname="item2"tye="radio"value=""sansan鹼粽label
# div
# divclass="continueAnswer"ahref="htts:vote.nownews.comanswer4028818a725dcf460172b69665dc3347login"繼續作答adiv
# div
# li
# ul
# scrit
# (function(d,a,b,l,e,_){
# if(d[b]&&d[b].q)return;
# d[b]=function(){
# (d[b].q=d[b].q||[]).ush(arguments)
# };
# e=a.createElement(l);
# e.async=1;
# e.charset='utf-8';
# e.src='static.dable.iodistlugin.min.js?v=20200620015227';
# _=a.getElementsByTagName(l)[0];
# _.arentNode.insertBefore(e,_);
# })(window,document,'dable','scrit');
# scrit
# div
# div
# divclass="wantviewMore"
# divclass="wantviewMoreLabel"想看更多div
# !--消息轮播--
# divclass="wantViewMore-container"id="wantViewMore"
# divclass="swier-wraer"
# divclass="swier-slide"
# aadkey="82"href="htts:bit.ly3ftvyJV"divclass="wantViewMoreImg"imgalt=""src="htts:ad2018.nownews.comstorageimagesCG3i3BDs3iJ4vUYylryj54ongOemcUGg16SVu0.jeg"div北京疫情捲土重來首都「進入非常時期」防二次感染潮成最大考驗a
# aadkey="83"href="htts:bit.ly2zHhGMK"divclass="wantViewMoreImg"imgalt=""src="htts:ad2018.nownews.comstorageimagesiXgblJnl4rtW1AayUxruRFXedcyPF3WDndY0t1E.jeg"div炎炎夏天中暑怎麼辦？如何緩解？怎麼預防？通通報你知a
# aadkey="84"href="htts:bit.ly3fyK3w0"divclass="wantViewMoreImg"imgalt=""src="htts:ad2018.nownews.comstorageimages1HNBWD1N4Lvum0YlMH95mwiKytvzL4F52UPa8kP9.jeg"div南北韓和平瓦解！金與正說到做到！兩韓聯絡處被炸毀戰爭一觸即發？a
# aadkey="85"href="htts:lay.nownews.comarchives331395"divclass="wantViewMoreImg"imgalt=""src="htts:ad2018.nownews.comstorageimag
divclass="wantViewMoreImg"imgalt=""src="htts:ad2018.nownews.comstorageimagesMtouFtQkG8sZO2BFoWiGjAdnPUUoOVbY7UXGSgu.jeg"div沒在跟你開玩笑！《瘋種菜》不只送「真蔬菜」還送黃金a
# div
# div
# divclass="swier-agination"div!--分页器。如果放置在swier-container外面，需要自定义样式。--
# div
# scrit
# varwantViewMoreSwier=newSwier('#wantViewMore',{
# autolay:6000,
# saceBetween:10,
# agination:{
# el:'.swier-agination',
# clickable:true,
# },
# loo:true
# });
# 鼠标移入停止自动播放
# document.getElementById("wantViewMore").onmouseover=function(){
# wantViewMoreSwier.stoAutolay()
# };
# document.getElementById("wantViewMore").onmouseout=function(){
# wantViewMoreSwier.startAutolay()
# };
# scrit
# div
# !--dable猜你喜歡--
# divclass="guessYouLikeadwad-dable-guessyoulike"div
# divclass="faceBookNote"
# divclass="fb-like"data-action="like"data-href="htts:www.nownews.comnewsolitics5022784"data-layout="button_count"data-share="true"data-show-faces="false"data-size="large"div
# divclass="fb-save"data-size="large"data-uri="htts:www.nownews.comnewsolitics5022784"div
# divclass="fb-comments"data-href="htts:www.nownews.comnewsolitics5022784"data-numosts="5"div
# div
# divclass="shareBox"
# !--facebook--
# divclass="share-button"data-href="htts:www.facebook.comsharer.h?u=htts:www.nownews.comnewsolitics5022784"
# imgalt=""src="imagesfacebook.ng"srcset=""div
# !--微博--
# divclass="share-button"data-href="htt:service.weibo.comshareshare.h?url=htts:www.nownews.comnewsolitics5022784&am;title=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識&am;language=zh_tw"
# imgalt=""src="imagesweibo.ng"srcset=""div
# !--推特--
# divclass="share-button"data-href="htts:twitter.comintenttweet?text=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識&am;url=htts:www.nownews.comnewsolitics5022784&am;via=NOWnews今日新聞"
# imgalt=""src="imagestwitter.ng"srcset=""div
# !--linea--
# divclass="share-button"data-href="htts:line.meRmsgtext?馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識%0D%0Ahtts:www.nownews.comnewsolitics5022784"
# imgalt=""src="imagesline.ng"srcset=""div
# !--telegram--
# divclass="share-button"data-href="htts:telegram.meshareurl?url=htts:www.nownews.comnewsolitics5022784&am;text=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識"
# imgalt=""src="imagestelegram.ng"srcset=""div
# !--领英--
# divclass="share-button"data-href="htts:www.linkedin.comshareArticle?mini=true&am;url=htts:www.nownews.comnewsolitics5022784&am;title=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識"
# imgalt=""src="imageslinkedin.ng"srcset=""div
# !--邮箱--
# divclass="share-button"data-href="mailto:?subject=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識&am;body=htts:www.nownews.comnewsolitics5022784"
# imgalt=""src="imagesemail.ng"srcset=""div
# !--打印--
# divclass="rint"data-href="#"imgalt=""src="imagesrint.ng"srcset=""div
# div
# !--網友看什麼,adname:eole-seen--
# divclass="friendWatchWhatadwad-eole-seen"div
# div
# !--新聞右側區域--
# divclass="newsContainerRight"
# !--右侧第一则广告--
# divclass="adadone"
# !--Nownews_olitical_article_300x250_RT_new2--
# divid="div-gt-ad-1497253737557-0"style="height:250x;width:300x;"val="'5799246Nownews_olitical_article_300x250_RT_new2',[300,250],'div-gt-ad-1497253737557-0'"
# scrit
# googletag.cmd.ush(function(){
# googletag.defineSlot('5799246Nownews_olitical_article_300x250_RT_new2',[300,250],'div-gt-ad-1497253737557-0').addService(googletag.ubads());
# googletag.ubads().enableSingleRequest();
# googletag.ubads().collaseEmtyDivs(true);
# googletag.enableServices();
# });
# googletag.cmd.ush(function(){googletag.dislay('div-gt-ad-1497253737557-0');});
# scrit
# div
# div
# !--即时模块--
# divclass="immediate"
# divclass="immTitle"
# imgalt=""src="imagesxiaoxi.ng"srcset=""
# san即時san
# div
# ul
# ul
# div
# !--右侧第二则广告--
# divclass="adadThree"
# !--Nownews_olitical_article_300x250_RM_new2--
# divid="div-gt-ad-1497253763874-0"style="height:250x;width:300x;"val="'5799246Nownews_olitical_article_300x250_RM_new2',[300,250],'div-gt-ad-1497253763874-0'"
# scrit
# googletag.cmd.ush(function(){
# googletag.defineSlot('5799246Nownews_olitical_article_300x250_RM_new2',[300,250],'div-gt-ad-1497253763874-0').addService(googletag.ubads());
# googletag.ubads().enableSingleRequest();
# googletag.ubads().collaseEmtyDivs(true);
# googletag.enableServices();
# });
# googletag.cmd.ush(function(){googletag.dislay('div-gt-ad-1497253763874-0');});
# scrit
# div
# div
# !--社群连接--
# divclass="grouConcat"
# divclass="gcFacebook"
# ahref="htts:www.facebook.comnownews"target="_blank"
# imgalt=""src="imagesfacebookIcon.ng"srcset=""
# san追蹤san
# a
# div
# divclass="gcToutube"
# ahref="htts:www.youtube.comchannelUCg8EwsqYmiw7G267xxPyXsg"target="_blank"
# imgalt=""src="imagesyoutube.ng"srcset=""san訂閱san
# a
# div
# divclass="gcIg"
# ahref="htts:www.instagram.comnownews"target="_blank"
# imgalt=""src="imagesins.ng"srcset=""san追蹤san
# a
# div
# div
# divclass="faceBookPage"
# iframeallow="encryted-media"allowtransarency="true"frameborder="0"height="500"scrolling="no"src="htts:www.facebook.comluginsage.h?href=htts%3A%2F%2Fwww.facebook.com%2Fnownews%2F&am;tabs=timeline&am;width=340&am;height=500&am;small_header=false&am;adat_container_width=true&am;hide_cover=false&am;show_faceile=true&am;aId=297786081079959&am;locale=zh_TW"style="border:none;overflow:hidden"width="340"iframe
# div
# !--關鍵字廣告,adname:keyword--
# divclass="adwad-right-keyword"div
# !--右侧第三则广告--
# divclass="adadFour"
# !--Nownews_olitical_article_300x250_RB_new2--
# divid="div-gt-ad-1497253791714-0"style="width:300x;"val="'5799246Nownews_olitical_article_300x250_RB_new2',[300,250],'div-gt-ad-1497253791714-0'"
# scrit
# googletag.cmd.ush(function(){
# googletag.defineSlot('5799246Nownews_olitical_article_300x250_RB_new2',[300,250],'div-gt-ad-1497253791714-0').addService(googletag.ubads());
# googletag.ubads().enableSingleRequest();
# googletag.ubads().collaseEmtyDivs(true);
# googletag.enableServices();
# });
# googletag.cmd.ush(function(){googletag.dislay('div-gt-ad-1497253791714-0');});
# scrit
# div
# div
# !--右侧第四则广告--
# divclass="adadFour"
# div
# !--推荐阅读--
# divclass="recommendRead"style=""
# divclass="closeRecommendReadBtn"imgalt=""src="imagesclose_recommend.jg"srcset=""
# div
# divclass="recommendReadTitle"推薦閱讀div
# ul
# li
# aadkey="47"href="htts:bit.ly2XqyDDc"
# 糖友選擇適當營養補充品　外食族控醣好幫手
# div
# imgalt="糖友選擇適當營養補充品　外食族控醣好幫手"src="htts:ad2018.nownews.comstorageimages821l3Db9erCYqouMMF2LXa2uWY5OiZBQxzoP3YWL.jeg"
# div
# a
# li
# li
# aadkey="48"href="htts:www.nownews.comnews5020763"
# 大學生該買「筆電」vs.「機車」　這款旗艦車終結論戰！
# div
# imgalt="大學生該買「筆電」vs.「機車」　這款旗艦車終結論戰！"src="htts:ad2018.nownews.comstorageimagesmRKUqBkh6Bm0ETEMR9ucazEm4tMiQnTMGcdys9I0.jeg"
# div
# a
# li
# li
# ahref="newsolitics4042224"
# 蘇貞昌宣布「已經在發現金了！」受惠對象下周請看存簿
# div
# imgalt="蘇貞昌宣布「已經在發現金了！」受惠對象下周請看存簿"src="htts:media.nownews.comnn_mediathumbnail2020031585275004-154ab3153a7237b3689ca88d66745014-800x600.jg"
# div
# a
# li
# li
# ahref="newsolitics3242595"
# 負債3千億兩個月還7百億？高雄真實債務曝光！網友全酸爆
# div
# imgalt="負債3千億兩個月還7百億？高雄真實債務曝光！網友全酸爆"src="htts:media.nownews.comnn_mediathumbnail2019021551067794-107095441962443bcd48bba95fb8c4f6-696x485.ng"
# div
# a
# li
# li
# ahref="newsolitics3025391"
# 擔心慘輸韓國瑜？陳其邁：我沒選上「會影響全台灣」
# div
# imgalt="擔心慘輸韓國瑜？陳其邁：我沒選上「會影響全台灣」"src="htts:media.nownews.comnn_mediathumbnail2018101540038592-3bc25e3ec7ee3135692b26d44efcae8b-696x391.jg"
# div
# a
# li
# ul
# div
# div
# div
# div
# divdivclass="to_banner_titlemargin20"
# class="fast_title"即時快訊
# !--快訊轮播--
# divclass="nowmsg-container"id="banner1"
# ulclass="twoNewsswier-wraer"
# ul
# div
# sanclass="title_san_first"san
# divclass="nowmsg-container"id="banner2"
# ulclass="twoNewsswier-wraer"
# ul
# div
# divdivclass="nowmsg-container"id="banner1"
# ulclass="twoNewsswier-wraer"
# ul
# divdivclass="nowmsg-container"id="banner2"
# ulclass="twoNewsswier-wraer"
# ul
# divdivclass="adwad-age-to"divdivclass="adwad-fruit-1"divdivclass="breadCrumbs"
# !--面包屑导航--
# ahref="htts:www.nownews.com"NOWnews今日新聞a
# &gt;ahref="catolitics"政治a
# divdivclass="hidedableadwad-dable-hidden"divdivclass="newsContainer"
# h3class="newsTitle"馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識h3
# divclass="newsInfo"記者吳承翰台北報導-2020-06-2107:56:39div
# divclass="newsBox"
# !--新聞左側區域--
# divclass="newsContainerLeft"
# divclass="shareBox"
# !--facebook--
# divclass="share-button"data-href="htts:www.facebook.comsharer.h?u=htts:www.nownews.comnewsolitics5022784"
# imgalt=""src="imagesfacebook.ng"srcset=""div
# !--微博--
# divclass="share-button"data-href="htt:service.weibo.comshareshare.h?url=htts:www.nownews.comnewsolitics5022784&am;title=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識&am;language=zh_tw"
# imgalt=""src="imagesweibo.ng"srcset=""div
# !--推特--
# divclass="share-button"data-href="htts:twitter.comintenttweet?text=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識&am;url=htts:www.nownews.comnewsolitics5022784&am;via=NOWnews今日新聞"
# imgalt=""src="imagestwitter.ng"srcset=""div
# !--linea--
# divclass="share-button"data-href="htts:line.meRmsgtext?馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識%0D%0Ahtts:www.nownews.comnewsolitics5022784"
# imgalt=""src="imagesline.ng"srcset=""div
# !--telegram--
# divclass="share-button"data-href="htts:telegram.meshareurl?url=htts:www.nownews.comnewsolitics5022784&am;text=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識"
# imgalt=""src="imagestelegram.ng"srcset=""div
# !--领英--
# divclass="share-button"data-href="htts:www.linkedin.comshareArticle?mini=true&am;url=htts:www.nownews.comnewsolitics5022784&am;title=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識"
# imgalt=""src="imageslinkedin.ng"srcset=""div
# !--邮箱--
# divclass="share-button"data-href="mailto:?subject=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識&am;body=htts:www.nownews.comnewsolitics5022784"
# imgalt=""src="imagesemail.ng"srcset=""div
# !--打印--
# divclass="rint"data-href="#"imgalt=""src="imagesrint.ng"srcset=""div
# div
# divclass="newsImg"
# imgalt=""src="htts:media.nownews.comnn_mediathumbnail2020061592697327718-7b69e037866f42e2862d2644c181fea8-800x370.jg?unShow=false"
# divclass="imgTitle"▲前國民黨主席朱立倫。(圖記者吳承翰攝)div
# div
# divclass="fontSizeChange"
# divclass="fontSizeSmall"fontsize="15"小div
# divclass="fontSizeMidactive"fontsize="17"中div
# divclass="fontSizeLarge"fontsize="19"大div
# div
# divclass="newsMsg"itemro="articleBody"
# 國民黨主席江啟臣日前宣布改革委員會討論成果，兩岸論述方面提sanstyle="background-color:rgb(255,255,255);color:rgb(34,34,34);"四大支柱，表明「九二共識是sansanstyle="background-color:rgb(255,255,255);color:rgb(59,59,59);"『過去』扮演兩岸求同存異的重要工具sansanstyle="background-color:rgb(255,255,255);color:rgb(34,34,34);"」。傳出此論述引起前總統馬英九、前副總統吳敦義的不滿，原先江邀請前黨主席們餐敘、共商改革及高雄補選，馬、吳san「因故」不便出席。21日朱立倫被問及此議題，他表示相關論述，還是要等到大家聚在一起時才好討論。brbr傳出黨中央憂心改革引起反彈，對於改革委員會的「建議」，仍要聽取基層意見，才會送交全代會通過，江啟臣也邀請歷任國民黨主席23日在黨秘書長李乾龍家餐敘、共商改革及高雄市長補選大計。brbr但在江啟臣發表九二共識是過去式的談話後，原先答應出席的馬英九、吳敦義改變立場，皆「因故」不出席餐敘，等同於不幫江啟臣背書。也曾在國民黨敗選後接下黨主席、前新北市長朱立倫說「我想黨的改革是很努力，大家可以多提供一些不同意見，最後再來凝聚共識，這段時間江主席很辛苦，大家多給改革委員會一些鼓勵吧。」brbr而對於馬英九、吳敦義皆堅持九二共識是國民黨兩岸論述的基礎，朱立倫說「這個我們目前因為還沒一起聚會，聚會在討論。」媒體問及在馬、吳皆不出席餐敘的情況下，他是否會赴約？朱立倫說「因為這個安排主要針對於高雄輔選，不管有沒有吃飯大家都會全力以赴討論高雄市補選。」brbr
#
# div
# !--其他人正在看--
# divclass="othersPeoleLookadwad-dable-watching"div
# !--文內廣告,adname:article-inside--
# divclass="adwad-article-inside"div
# !--影片廣告truvidorviewdeos--
# divclass="truvidadwad-video-mixin"data-category="olitics"div
# divclass="keywordBox"
# divclass="keywordLabel"NOWnews關鍵字div
# divclass="keyWordContent"
# div
# ahref="tag.html?name=zN5DBrLD9X"朱立倫a
# div
# div
# ahref="tag.html?name=QKw8gaKo2q"馬英九a
# div
# div
# ahref="tag.html?name=V1e7wnoZy"九二共識a
# div
# div
# ahref="tag.html?name=OlQ8LjVoe5"江啟臣a
# div
# div
# ahref="tag.html?name=LGoYElxbom"吳敦樣a
# div
# div
# div
# !--果實廣告,adname:fruit-2--
# divclass="adwad-fruit-2"div
# divclass="extendRead"
# divclass="readLabel"延伸閱讀div
# divclass="readList"
# ul
# liahref="htts:www.nownews.comnewsolitics5022209"再見了九二共識！江啟臣澄清：國民黨絕非「小綠」ali
# liahref="htts:www.nownews.comnewsolitics5022029"黃健庭接監院　江啟臣：遺憾！相信不至於出現「跳船潮」ali
# liaadkey="73"href="htts:bit.ly3hyAa3h"投資人莫慌！後疫情時代怎投資　AI「存基金」鎖定雙技美ali
# liahref="htts:www.nownews.comnewsolitics5021433"江啟臣宣布黨產歸零！全捐公務員和勞工退休基金兼做公益ali
# ul
# ul
# liahref="newsolitics5021305"二備金拍宣傳片黃珊珊扯馬郝　游淑慧嗆：別學柯文哲賴皮ali
# liaadkey="74"href="htts:www.nownews.comcatfinancefund-investment"投資從小額開始！找不到標的、不會投資都看這ali
# liahref="newsolitics5021237"用二備金宣傳台北大縱走挨批　黃珊珊酸：馬郝時代花更多ali
# liid="_oIn_recommend_word"li
# ul
# div
# div
# !--NOW民調調查局--
# divclass="bureauInvestigation"
# divclass="biLabel"NOW民調中心div
# divclass="biList"
# ul
# li
# aclass="biTo"href="htts:vote.nownews.comanswer4028818a72cbf2130172d0968039176flogin"
# div
# imgdata-original="htts:vote.nownews.comimagesquestion4028818a72cbf2130172d0968039176fimg"src="htts:vote.nownews.comimagesquestion4028818a72cbf2130172d0968039176fimg"
# div
# class="biTitle"您怎麼看這次的監察院風波？
# a
# divclass="biBottom"
# divclass="radioBox"
# labelinutname="item0"tye="radio"value=""sansan贊成，陳菊相當適任。label
# labelinutname="item0"tye="radio"value=""sansan不贊成，監察院長應該由超黨派人選出任。label
# labelinutname="item0"tye="radio"value=""sansan沒意見。label
# div
# divclass="continueAnswer"ahref="htts:vote.nownews.comanswer4028818a72cbf2130172d0968039176flogin"繼續作答adiv
# div
# li
# li
# aclass="biTo"href="htts:vote.nownews.comanswer4028818a725dcf460172c65537b1264elogin"
# div
# imgdata-original="htts:vote.nownews.comimagesquestion4028818a725dcf460172c65537b1264eimg"src="htts:vote.nownews.comimagesquestion4028818a725dcf460172c65537b1264eimg"
# div
# class="biTitle"炎炎夏日來臨！哪首南韓女團的夏季作品最讓你聽不膩？
# a
# divclass="biBottom"
# divclass="radioBox"
# labelinutname="item1"tye="radio"value=""sansan少女時代《Party》label
# labelinutname="item1"tye="radio"value=""sansanSISTAR《TOUCHMYBODY》label
# labelinutname="item1"tye="radio"value=""sansanf(x)《HOTSUMMER》label
# div
# divclass="continueAnswer"ahref="htts:vote.nownews.comanswer4028818a725dcf460172c65537b1264elogin"繼續作答adiv
# div
# li
# li
# aclass="biTo"href="htts:vote.nownews.comanswer4028818a725dcf460172b69665dc3347login"
# div
# imgdata-original="htts:vote.nownews.comimagesquestion4028818a725dcf460172b69665dc3347img"src="htts:vote.nownews.comimagesquestion4028818a725dcf460172b69665dc3347img"
# div
# class="biTitle"[抽獎]端午粽子大戰！您覺得今年哪種粽會最受歡迎？
# a
# divclass="biBottom"
# divclass="radioBox"
# labelinutname="item2"tye="radio"value=""sansan南部粽label
# labelinutname="item2"tye="radio"value=""sansan北部粽label
# labelinutname="item2"tye="radio"value=""sansan鹼粽label
# div
# divclass="continueAnswer"ahref="htts:vote.nownews.comanswer4028818a725dcf460172b69665dc3347login"繼續作答adiv
# div
# li
# ul
# scrit
# (function(d,a,b,l,e,_){
# if(d[b]&&d[b].q)return;
# d[b]=function(){
# (d[b].q=d[b].q||[]).ush(arguments)
# };
# e=a.createElement(l);
# e.async=1;
# e.charset='utf-8';
# e.src='static.dable.iodistlugin.min.js?v=20200620015227';
# _=a.getElementsByTagName(l)[0];
# _.arentNode.insertBefore(e,_);
# })(window,document,'dable','scrit');
# scrit
# div
# div
# divclass="wantviewMore"
# divclass="wantviewMoreLabel"想看更多div
# !--消息轮播--
# divclass="wantViewMore-container"id="wantViewMore"
# divclass="swier-wraer"
# divclass="swier-slide"
# aadkey="82"href="htts:bit.ly3ftvyJV"divclass="wantViewMoreImg"imgalt=""src="htts:ad2018.nownews.comstorageimagesCG3i3BDs3iJ4vUYylryj54ongOemcUGg16SVu0.jeg"div北京疫情捲土重來首都「進入非常時期」防二次感染潮成最大考驗a
# aadkey="83"href="htts:bit.ly2zHhGMK"divclass="wantViewMoreImg"imgalt=""src="htts:ad2018.nownews.comstorageimagesiXgblJnl4rtW1AayUxruRFXedcyPF3WDndY0t1E.jeg"div炎炎夏天中暑怎麼辦？如何緩解？怎麼預防？通通報你知a
# aadkey="84"href="htts:bit.ly3fyK3w0"divclass="wantViewMoreImg"imgalt=""src="htts:ad2018.nownews.comstorageimages1HNBWD1N4Lvum0YlMH95mwiKytvzL4F52UPa8kP9.jeg"div南北韓和平瓦解！金與正說到做到！兩韓聯絡處被炸毀戰爭一觸即發？a
# aadkey="85"href="htts:lay.nownews.comarchives331395"divclass="wantViewMoreImg"imgalt=""src="htts:ad2018.nownews.comstorageimagesSTXRiyPZn2EF5YvluSWYmJatKYa5DYAVE5RBwMxc.ng"div再度零確診！迎戰五一連假　百貨推有驚無險保庇券a
# aadkey="86"href="htts:bit.ly3d136gI"divclass="wantViewMoreImg"imgalt=""src="htts:ad2018.nownews.comstorageimages1zUa2QBeLN0Ntt1jcgsEtiDnVzRxOt1vZhKI.jeg"div端午粽香乓共共！全台名店、創意粽子推薦排行榜甜的鹹的通通有a
# aadkey="87"href="htts:bit.ly2YNLiAL"divclass="wantViewMoreImg"imgalt=""src="htts:ad2018.nownews.comstorageimages32kiW5OAmD71Nw9yIUCalgNmtOLA66Frl6d4bo.jeg"div新房入住的10個禁忌！不注意恐破財、傷身！a
# div
# divclass="swier-slide"
# aadkey="88"href="htts:bit.ly3hmQxzO"divclass="wantViewMoreImg"imgalt=""src="htts:ad2018.nownews.comstorageimagesOnvtydkLxDnHNxm9zRcLz74evLxyrCyxhsVEB3Fe.jeg"div「小確幸」來了!文化部發放600元「藝Fun券」愛買書、愛看電影的722準時開搶a
# aadkey="89"href="htts:bit.ly3hBAZZ2"divclass="wantViewMoreImg"imgalt=""src="htts:ad2018.nownews.comstorageimagesg9TiVhgH4nRsxzcVH5EONCJUbxdXHELl2OmYiJ.jeg"div防疫不鬆懈！鼻病毒、漢他病毒來勢洶洶還有5大夏季傳染病正流行a
# aadkey="90"href="htts:bit.ly2NciQ5S"divclass="wantViewMoreImg"imgalt=""src="htts:ad2018.nownews.comstorageimagesti7YsMsF4HKMhZiMCotbARg1Ieewy4WIYUgULU0E.jeg"div艷陽高溫都不怕！蒐羅IG瘋打卡的夏日消暑聖品a
# aadkey="91"href="htts:lay.nownews.comarchives331428"divclass="wantViewMoreImg"imgalt=""src="htts:ad2018.nownews.comstorageimagestODIU68ViliHk962i69I9wxkWbm4VH1elM61u.ng"div帶媽媽吃「原味」大餐訂位送「馬告飛魚XO醬」a
# aadkey="92"href="htts:bit.ly3fF2O0U"divclass="wantViewMoreImg"imgalt=""src="htts:ad2018.nownews.comstorageimagesmRoQ1NCRt2fSGlqDg4cIo4qYIYdmxuy0NZFVeMF.jeg"div疫情趨緩！終於可以出來透透氣抽張牌看看『現在的你』最適合什麼解壓方式？a
# aadkey="93"href="htts:suerstar.nownews.com"divclass="wantViewMoreImg"imgalt=""src="htts:ad2018.nownews.comstorageimagesfJalnOTjzeSsQ5GchfHoGKOeSCWVl5Mr9wSqHSsT.gif"div平民巨星即將播出》選手唱太好巨星導師選不出a
# div
# divclass="swier-slide"
# aadkey="94"href="htts:bit.ly30P7RYn"divclass="wantViewMoreImg"imgalt=""src="htts:ad2018.nownews.comstorageimagesPPb5tzTIS49vEKswFN6xfPquBE85aZQ52Z9iXWzf.jeg"div你好毒，你好毒，你好毒毒毒毒毒！看不見的居家健康隱藏危機！a
# aadkey="96"href="htts:bit.ly3ecQhl1"divclass="wantViewMoreImg"imgalt=""src="htts:ad2018.nownews.comstorageimagesyJrXUy86WI4JYnKa76iOBtKEoffKn9nAz1WoM1Gz.jeg"div在家工作快被主子逼瘋？男子一招神技解決：把貓咪「收納」a
# aadkey="97"href="htts:lay.nownews.comarchives331227"divclass="wantViewMoreImg"imgalt=""src="htts:ad2018.nownews.comstorageimages4C8W18uKVySUXaktsliP0JYu3i9uL4Zr1k724lXy.ng"div華泰王子大飯店九華樓X驢子餐廳料理中西軍母親節外帶限定a
# aadkey="98"href="htts:bit.ly2ZFfHmI"divclass="wantViewMoreImg"imgalt=""src="htts:ad2018.nownews.comstorageimagesqScAK3QI5FlImI6ThXQicn53oA98L6T3TB5cEgT.jeg"div61口罩禁令解除！自由販售價格恐高於實名制，該怎麼買一次看清楚！a
# aadkey="99"href="htts:bit.ly2YKA2VE"divclass="wantViewMoreImg"imgalt=""src="htts:ad2018.nownews.comstorageimagesMXfAPZMK0qtWKDsn9mgfcFiZi7QQx1jiVYimwmIs.jeg"div美國八個神秘懸案多年未解至今仍然讓人匪夷所思a
# aadkey="100"href="htts:www.nownews.comnews5007455"divclass="wantViewMoreImg"imgalt=""src="htts:ad2018.nownews.comstorageimagesMtouFtQkG8sZO2BFoWiGjAdnPUUoOVbY7UXGSgu.jeg"div沒在跟你開玩笑！《瘋種菜》不只送「真蔬菜」還送黃金a
# div
# div
# divclass="swier-agination"div!--分页器。如果放置在swier-container外面，需要自定义样式。--
# div
# scrit
# varwantViewMoreSwier=newSwier('#wantViewMore',{
# autolay:6000,
# saceBetween:10,
# agination:{
# el:'.swier-agination',
# clickable:true,
# },
# loo:true
# });
# 鼠标移入停止自动播放
# document.getElementById("wantViewMore").onmouseover=function(){
# wantViewMoreSwier.stoAutolay()
# };
# document.getElementById("wantViewMore").onmouseout=function(){
# wantViewMoreSwier.startAutolay()
# };
# scrit
# div
# !--dable猜你喜歡--
# divclass="guessYouLikeadwad-dable-guessyoulike"div
# divclass="faceBookNote"
# divclass="fb-like"data-action="like"data-href="htts:www.nownews.comnewsolitics5022784"data-layout="button_count"data-share="true"data-show-faces="false"data-size="large"div
# divclass="fb-save"data-size="large"data-uri="htts:www.nownews.comnewsolitics5022784"div
# divclass="fb-comments"data-href="htts:www.nownews.comnewsolitics5022784"data-numosts="5"div
# div
# divclass="shareBox"
# !--facebook--
# divclass="share-button"data-href="htts:www.facebook.comsharer.h?u=htts:www.nownews.comnewsolitics5022784"
# imgalt=""src="imagesfacebook.ng"srcset=""div
# !--微博--
# divclass="share-button"data-href="htt:service.weibo.comshareshare.h?url=htts:www.nownews.comnewsolitics5022784&am;title=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識&am;language=zh_tw"
# imgalt=""src="imagesweibo.ng"srcset=""div
# !--推特--
# divclass="share-button"data-href="htts:twitter.comintenttweet?text=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識&am;url=htts:www.nownews.comnewsolitics5022784&am;via=NOWnews今日新聞"
# imgalt=""src="imagestwitter.ng"srcset=""div
# !--linea--
# divclass="share-button"data-href="htts:line.meRmsgtext?馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識%0D%0Ahtts:www.nownews.comnewsolitics5022784"
# imgalt=""src="imagesline.ng"srcset=""div
# !--telegram--
# divclass="share-button"data-href="htts:telegram.meshareurl?url=htts:www.nownews.comnewsolitics5022784&am;text=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識"
# imgalt=""src="imagestelegram.ng"srcset=""div
# !--领英--
# divclass="share-button"data-href="htts:www.linkedin.comshareArticle?mini=true&am;url=htts:www.nownews.comnewsolitics5022784&am;title=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識"
# imgalt=""src="imageslinkedin.ng"srcset=""div
# !--邮箱--
# ...
# imgalt=""src="imagesfacebook.ng"srcset=""divdivclass="share-button"data-href="htt:service.weibo.comshareshare.h?url=htts:www.nownews.comnewsolitics5022784&am;title=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識&am;language=zh_tw"
# imgalt=""src="imagesweibo.ng"srcset=""divdivclass="share-button"data-href="htts:twitter.comintenttweet?text=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識&am;url=htts:www.nownews.comnewsolitics5022784&am;via=NOWnews今日新聞"
# imgalt=""src="imagestwitter.ng"srcset=""divdivclass="share-button"data-href="htts:line.meRmsgtext?馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識%0D%0Ahtts:www.nownews.comnewsolitics5022784"
# imgalt=""src="imagesline.ng"srcset=""divdivclass="share-button"data-href="htts:telegram.meshareurl?url=htts:www.nownews.comnewsolitics5022784&am;text=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識"
# imgalt=""src="imagestelegram.ng"srcset=""divdivclass="share-button"data-href="htts:www.linkedin.comshareArticle?mini=true&am;url=htts:www.nownews.comnewsolitics5022784&am;title=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識"
# imgalt=""src="imageslinkedin.ng"srcset=""divdivclass="share-button"data-href="mailto:?subject=馬英九、吳敦義拒赴江啟臣餐敘　朱立倫：還要凝聚共識&am;body=htts:www.nownews.comnewsolitics5022784"
# imgalt=""src="imagesemail.ng"srcset=""divdivclass="rint"data-href="#"imgalt=""src="imagesrint.ng"srcset=""divdivclass="friendWatchWhatadwad-eole-seen"divdivclass="newsContainerRight"
# !--右侧第一则广告--
# divclass="adadone"
# !--Nownews_olitical_article_300x250_RT_new2--
# divid="div-gt-ad-1497253737557-0"style="height:250x;width:300x;"val="'5799246Nownews_olitical_article_300x250_RT_new2',[300,250],'div-gt-ad-1497253737557-0'"
# scrit
# googletag.cmd.ush(function(){
# googletag.defineSlot('5799246Nownews_olitical_article_300x250_RT_new2',[300,250],'div-gt-ad-1497253737557-0').addService(googletag.ubads());
# googletag.ubads().enableSingleRequest();
# googletag.ubads().collaseEmtyDivs(true);
# googletag.enableServices();
# });
# googletag.cmd.ush(function(){googletag.dislay('div-gt-ad-1497253737557-0');});
# scrit
# div
# div
# !--即时模块--
# divclass="immediate"
# divclass="immTitle"
# imgalt=""src="imagesxiaoxi.ng"srcset=""
# san即時san
# div
# ul
# ul
# div
# !--右侧第二则广告--
# divclass="adadThree"
# !--Nownews_olitical_article_300x250_RM_new2--
# divid="div-gt-ad-1497253763874-0"style="height:250x;width:300x;"val="'5799246Nownews_olitical_article_300x250_RM_new2',[300,250],'div-gt-ad-1497253763874-0'"
# scrit
# googletag.cmd.ush(function(){
# googletag.defineSlot('5799246Nownews_olitical_article_300x250_RM_new2',[300,250],'div-gt-ad-1497253763874-0').addService(googletag.ubads());
# googletag.ubads().enableSingleRequest();
# googletag.ubads().collaseEmtyDivs(true);
# googletag.enableServices();
# });
# googletag.cmd.ush(function(){googletag.dislay('div-gt-ad-1497253763874-0');});
# scrit
# div
# div
# !--社群连接--
# divclass="grouConcat"
# divclass="gcFacebook"
# ahref="htts:www.facebook.comnownews"target="_blank"
# imgalt=""src="imagesfacebookIcon.ng"srcset=""
# san追蹤san
# a
# div
# divclass="gcToutube"
# ahref="htts:www.youtube.comchannelUCg8EwsqYmiw7G267xxPyXsg"target="_blank"
# imgalt=""src="imagesyoutube.ng"srcset=""san訂閱san
# a
# div
# divclass="gcIg"
# ahref="htts:www.instagram.comnownews"target="_blank"
# imgalt=""src="imagesins.ng"srcset=""san追蹤san
# a
# div
# div
# divclass="faceBookPage"
# iframeallow="encryted-media"allowtransarency="true"frameborder="0"height="500"scrolling="no"src="htts:www.facebook.comluginsage.h?href=htts%3A%2F%2Fwww.facebook.com%2Fnownews%2F&am;tabs=timeline&am;width=340&am;height=500&am;small_header=false&am;adat_container_width=true&am;hide_cover=false&am;show_faceile=true&am;aId=297786081079959&am;locale=zh_TW"style="border:none;overflow:hidden"width="340"iframe
# div
# !--關鍵字廣告,adname:keyword--
# divclass="adwad-right-keyword"div
# !--右侧第三则广告--
# divclass="adadFour"
# !--Nownews_olitical_article_300x250_RB_new2--
# divid="div-gt-ad-1497253791714-0"style="width:300x;"val="'5799246Nownews_olitical_article_300x250_RB_new2',[300,250],'div-gt-ad-1497253791714-0'"
# scrit
# googletag.cmd.ush(function(){
# googletag.defineSlot('5799246Nownews_olitical_article_300x250_RB_new2',[300,250],'div-gt-ad-1497253791714-0').addService(googletag.ubads());
# googletag.ubads().enableSingleRequest();
# googletag.ubads().collaseEmtyDivs(true);
# googletag.enableServices();
# });
# googletag.cmd.ush(function(){googletag.dislay('div-gt-ad-1497253791714-0');});
# scrit
# div
# div
# !--右侧第四则广告--
# divclass="adadFour"
# div
# !--推荐阅读--
# divclass="recommendRead"style=""
# divclass="closeRecommendReadBtn"imgalt=""src="imagesclose_recommend.jg"srcset=""
# div
# divclass="recommendReadTitle"推薦閱讀div
# ul
# li
# aadkey="47"href="htts:bit.ly2XqyDDc"
# 糖友選擇適當營養補充品　外食族控醣好幫手
# div
# imgalt="糖友選擇適當營養補充品　外食族控醣好幫手"src="htts:ad2018.nownews.comstorageimages821l3Db9erCYqouMMF2LXa2uWY5OiZBQxzoP3YWL.jeg"
# div
# a
# li
# li
# aadkey="48"href="htts:www.nownews.comnews5020763"
# 大學生該買「筆電」vs.「機車」　這款旗艦車終結論戰！
# div
# imgalt="大學生該買「筆電」vs.「機車」　這款旗艦車終結論戰！"src="htts:ad2018.nownews.comstorageimagesmRKUqBkh6Bm0ETEMR9ucazEm4tMiQnTMGcdys9I0.jeg"
# div
# a
# li
# li
# ahref="newsolitics4042224"
# 蘇貞昌宣布「已經在發現金了！」受惠對象下周請看存簿
# div
# imgalt="蘇貞昌宣布「已經在發現金了！」受惠對象下周請看存簿"src="htts:media.nownews.comnn_mediathumbnail2020031585275004-154ab3153a7237b3689ca88d66745014-800x600.jg"
# div
# a
# li
# li
# ahref="newsolitics3242595"
# 負債3千億兩個月還7百億？高雄真實債務曝光！網友全酸爆
# div
# imgalt="負債3千億兩個月還7百億？高雄真實債務曝光！網友全酸爆"src="htts:media.nownews.comnn_mediathumbnail2019021551067794-107095441962443bcd48bba95fb8c4f6-696x485.ng"
# div
# a
# li
# li
# ahref="newsolitics3025391"
# 擔心慘輸韓國瑜？陳其邁：我沒選上「會影響全台灣」
# div
# imgalt="擔心慘輸韓國瑜？陳其邁：我沒選上「會影響全台灣」"src="htts:media.nownews.comnn_mediathumbnail2018101540038592-3bc25e3ec7ee3135692b26d44efcae8b-696x391.jg"
# div
# a
# li
# ul
# div
# divdivclass="adadone"
# !--Nownews_olitical_article_300x250_RT_new2--
# divid="div-gt-ad-1497253737557-0"style="height:250x;width:300x;"val="'5799246Nownews_olitical_article_300x250_RT_new2',[300,250],'div-gt-ad-1497253737557-0'"
# scrit
# googletag.cmd.ush(function(){
# googletag.defineSlot('5799246Nownews_olitical_article_300x250_RT_new2',[300,250],'div-gt-ad-1497253737557-0').addService(googletag.ubads());
# googletag.ubads().enableSingleRequest();
# googletag.ubads().collaseEmtyDivs(true);
# googletag.enableServices();
# });
# googletag.cmd.ush(function(){googletag.dislay('div-gt-ad-1497253737557-0');});
# scrit
# div
# divdivid="div-gt-ad-1497253737557-0"style="height:250x;width:300x;"val="'5799246Nownews_olitical_article_300x250_RT_new2',[300,250],'div-gt-ad-1497253737557-0'"
# scrit
# googletag.cmd.ush(function(){
# googletag.defineSlot('5799246Nownews_olitical_article_300x250_RT_new2',[300,250],'div-gt-ad-1497253737557-0').addService(googletag.ubads());
# googletag.ubads().enableSingleRequest();
# googletag.ubads().collaseEmtyDivs(true);
# googletag.enableServices();
# });
# googletag.cmd.ush(function(){googletag.dislay('div-gt-ad-1497253737557-0');});
# scrit
# divdivclass="immediate"
# divclass="immTitle"
# imgalt=""src="imagesxiaoxi.ng"srcset=""
# san即時san
# div
# ul
# ul
# divdivclass="immTitle"
# imgalt=""src="imagesxiaoxi.ng"srcset=""
# san即時san
# divdivclass="adadThree"
# !--Nownews_olitical_article_300x250_RM_new2--
# divid="div-gt-ad-1497253763874-0"style="height:250x;width:300x;"val="'5799246Nownews_olitical_article_300x250_RM_new2',[300,250],'div-gt-ad-1497253763874-0'"
# scrit
# googletag.cmd.ush(function(){
# googletag.defineSlot('5799246Nownews_olitical_article_300x250_RM_new2',[300,250],'div-gt-ad-1497253763874-0').addService(googletag.ubads());
# googletag.ubads().enableSingleRequest();
# googletag.ubads().collaseEmtyDivs(true);
# googletag.enableServices();
# });
# googletag.cmd.ush(function(){googletag.dislay('div-gt-ad-1497253763874-0');});
# scrit
# div
# divdivid="div-gt-ad-1497253763874-0"style="height:250x;width:300x;"val="'5799246Nownews_olitical_article_300x250_RM_new2',[300,250],'div-gt-ad-1497253763874-0'"
# scrit
# googletag.cmd.ush(function(){
# googletag.defineSlot('5799246Nownews_olitical_article_300x250_RM_new2',[300,250],'div-gt-ad-1497253763874-0').addService(googletag.ubads());
# googletag.ubads().enableSingleRequest();
# googletag.ubads().collaseEmtyDivs(true);
# googletag.enableServices();
# });
# googletag.cmd.ush(function(){googletag.dislay('div-gt-ad-1497253763874-0');});
# scrit
# divdivclass="grouConcat"
# divclass="gcFacebook"
# ahref="htts:www.facebook.comnownews"target="_blank"
# imgalt=""src="imagesfacebookIcon.ng"srcset=""
# san追蹤san
# a
# div
# divclass="gcToutube"
# ahref="htts:www.youtube.comchannelUCg8EwsqYmiw7G267xxPyXsg"target="_blank"
# imgalt=""src="imagesyoutube.ng"srcset=""san訂閱san
# a
# div
# divclass="gcIg"
# ahref="htts:www.instagram.comnownews"target="_blank"
# imgalt=""src="imagesins.ng"srcset=""san追蹤san
# a
# div
# divdivclass="gcFacebook"
# ahref="htts:www.facebook.comnownews"target="_blank"
# imgalt=""src="imagesfacebookIcon.ng"srcset=""
# san追蹤san
# a
# divdivclass="gcToutube"
# ahref="htts:www.youtube.comchannelUCg8EwsqYmiw7G267xxPyXsg"target="_blank"
# imgalt=""src="imagesyoutube.ng"srcset=""san訂閱san
# a
# divdivclass="gcIg"
# ahref="htts:www.instagram.comnownews"target="_blank"
# imgalt=""src="imagesins.ng"srcset=""san追蹤san
# a
# divdivclass="faceBookPage"
# iframeallow="encryted-media"allowtransarency="true"frameborder="0"height="500"scrolling="no"src="htts:www.facebook.comluginsage.h?href=htts%3A%2F%2Fwww.facebook.com%2Fnownews%2F&am;tabs=timeline&am;width=340&am;height=500&am;small_header=false&am;adat_container_width=true&am;hide_cover=false&am;show_faceile=true&am;aId=297786081079959&am;locale=zh_TW"style="border:none;overflow:hidden"width="340"iframe
# divdivclass="adwad-right-keyword"divdivclass="adadFour"
# !--Nownews_olitical_article_300x250_RB_new2--
# divid="div-gt-ad-1497253791714-0"style="width:300x;"val="'5799246Nownews_olitical_article_300x250_RB_new2',[300,250],'div-gt-ad-1497253791714-0'"
# scrit
# googletag.cmd.ush(function(){
# googletag.defineSlot('5799246Nownews_olitical_article_300x250_RB_new2',[300,250],'div-gt-ad-1497253791714-0').addService(googletag.ubads());
# googletag.ubads().enableSingleRequest();
# googletag.ubads().collaseEmtyDivs(true);
# googletag.enableServices();
# });
# googletag.cmd.ush(function(){googletag.dislay('div-gt-ad-1497253791714-0');});
# scrit
# div
# divdivid="div-gt-ad-1497253791714-0"style="width:300x;"val="'5799246Nownews_olitical_article_300x250_RB_new2',[300,250],'div-gt-ad-1497253791714-0'"
# scrit
# googletag.cmd.ush(function(){
# googletag.defineSlot('5799246Nownews_olitical_article_300x250_RB_new2',[300,250],'div-gt-ad-1497253791714-0').addService(googletag.ubads());
# googletag.ubads().enableSingleRequest();
# googletag.ubads().collaseEmtyDivs(true);
# googletag.enableServices();
# });
# googletag.cmd.ush(function(){googletag.dislay('div-gt-ad-1497253791714-0');});
# scrit
# divdivclass="adadFour"
# divdivclass="recommendRead"style=""
# divclass="closeRecommendReadBtn"imgalt=""src="imagesclose_recommend.jg"srcset=""
# div
# divclass="recommendReadTitle"推薦閱讀div
# ul
# li
# aadkey="47"href="htts:bit.ly2XqyDDc"
# 糖友選擇適當營養補充品　外食族控醣好幫手
# div
# imgalt="糖友選擇適當營養補充品　外食族控醣好幫手"src="htts:ad2018.nownews.comstorageimages821l3Db9erCYqouMMF2LXa2uWY5OiZBQxzoP3YWL.jeg"
# div
# a
# li
# li
# aadkey="48"href="htts:www.nownews.comnews5020763"
# 大學生該買「筆電」vs.「機車」　這款旗艦車終結論戰！
# div
# imgalt="大學生該買「筆電」vs.「機車」　這款旗艦車終結論戰！"src="htts:ad2018.nownews.comstorageimagesmRKUqBkh6Bm0ETEMR9ucazEm4tMiQnTMGcdys9I0.jeg"
# div
# a
# li
# li
# ahref="newsolitics4042224"
# 蘇貞昌宣布「已經在發現金了！」受惠對象下周請看存簿
# div
# imgalt="蘇貞昌宣布「已經在發現金了！」受惠對象下周請看存簿"src="htts:media.nownews.comnn_mediathumbnail2020031585275004-154ab3153a7237b3689ca88d66745014-800x600.jg"
# div
# a
# li
# li
# ahref="newsolitics3242595"
# 負債3千億兩個月還7百億？高雄真實債務曝光！網友全酸爆
# div
# imgalt="負債3千億兩個月還7百億？高雄真實債務曝光！網友全酸爆"src="htts:media.nownews.comnn_mediathumbnail2019021551067794-107095441962443bcd48bba95fb8c4f6-696x485.ng"
# div
# a
# li
# li
# ahref="newsolitics3025391"
# 擔心慘輸韓國瑜？陳其邁：我沒選上「會影響全台灣」
# div
# imgalt="擔心慘輸韓國瑜？陳其邁：我沒選上「會影響全台灣」"src="htts:media.nownews.comnn_mediathumbnail2018101540038592-3bc25e3ec7ee3135692b26d44efcae8b-696x391.jg"
# div
# a
# li
# ul
# divdivclass="closeRecommendReadBtn"imgalt=""src="imagesclose_recommend.jg"srcset=""
# divdivclass="recommendReadTitle"推薦閱讀divdiv
# imgalt="糖友選擇適當營養補充品　外食族控醣好幫手"src="htts:ad2018.nownews.comstorageimages821l3Db9erCYqouMMF2LXa2uWY5OiZBQxzoP3YWL.jeg"
# divdiv
# imgalt="大學生該買「筆電」vs.「機車」　這款旗艦車終結論戰！"src="htts:ad2018.nownews.comstorageimagesmRKUqBkh6Bm0ETEMR9ucazEm4tMiQnTMGcdys9I0.jeg"
# divdiv
# imgalt="蘇貞昌宣布「已經在發現金了！」受惠對象下周請看存簿"src="htts:media.nownews.comnn_mediathumbnail2020031585275004-154ab3153a7237b3689ca88d66745014-800x600.jg"
# divdiv
# imgalt="負債3千億兩個月還7百億？高雄真實債務曝光！網友全酸爆"src="htts:media.nownews.comnn_mediathumbnail2019021551067794-107095441962443bcd48bba95fb8c4f6-696x485.ng"
# divdiv
# imgalt="擔心慘輸韓國瑜？陳其邁：我沒選上「會影響全台灣」"src="htts:media.nownews.comnn_mediathumbnail2018101540038592-3bc25e3ec7ee3135692b26d44efcae8b-696x391.jg"
# divdivclass="section-social"
# ul
# li
# ahref="htts:www.facebook.comnownews"target="_blank"imgalt=""src="imagesfooterfacebook.ng"a
# li
# li
# ahref="htts:www.instagram.comnownews"target="_blank"imgalt=""src="imagesfooterins.ng"a
# li
# li
# ahref="htts:www.youtube.comchannelUCg8EwsqYmiw7G267xxPyXsg"target="_blank"imgalt=""src="imagesfooteryoutube.ng"a
# li
# li
# ahref="htts:www.weibo.comnownews"target="_blank"imgalt=""src="imagesfooterweibo.ng"a
# li
# li
# ahref="htt:line.meti@nownews"target="_blank"imgalt=""src="imagesfooterline.ng"a
# li
# ul
# divdivclass="section-footer"
# divclass="container"
# div
# san
# ©今日傳媒(股)公司版權所有，非經授權，不許轉載本網站內容
# san
# san
# ©2017NOWnews.com.AllRightsReserved.
# san
# div
# divclass="addressUri"
# ul
# liclass="activeAddress"
# ahref="disclaimer.html"style="color:#FFFFFF;"target="_blank"免責聲明a
# li
# li
# ahref="rivacy.html"style="color:#FFFFFF;"target="_blank"隱私權聲明a
# li
# li
# ahref="coyright.html"style="color:#FFFFFF;"target="_blank"著作權聲明a
# li
# li
# ahref="aboutus.html"style="color:#FFFFFF;"target="_blank"關於我們a
# li
# li
# ahref="1536223982-688478b05681a795fa9df223e2857cd2.df"style="color:#FFFFFF;"target="_blank"合作提案a
# li
# ul
# div
# div
# divdivclass="container"
# div
# san
# ©今日傳媒(股)公司版權所有，非經授權，不許轉載本網站內容
# san
# san
# ©2017NOWnews.com.AllRightsReserved.
# san
# div
# divclass="addressUri"
# ul
# liclass="activeAddress"
# ahref="disclaimer.html"style="color:#FFFFFF;"target="_blank"免責聲明a
# li
# li
# ahref="rivacy.html"style="color:#FFFFFF;"target="_blank"隱私權聲明a
# li
# li
# ahref="coyright.html"style="color:#FFFFFF;"target="_blank"著作權聲明a
# li
# li
# ahref="aboutus.html"style="color:#FFFFFF;"target="_blank"關於我們a
# li
# li
# ahref="1536223982-688478b05681a795fa9df223e2857cd2.df"style="color:#FFFFFF;"target="_blank"合作提案a
# li
# ul
# div
# divdiv
# san
# ©今日傳媒(股)公司版權所有，非經授權，不許轉載本網站內容
# san
# san
# ©2017NOWnews.com.AllRightsReserved.
# san
# divdivclass="addressUri"
# ul
# liclass="activeAddress"
# ahref="disclaimer.html"style="color:#FFFFFF;"target="_blank"免責聲明a
# li
# li
# ahref="rivacy.html"style="color:#FFFFFF;"target="_blank"隱私權聲明a
# li
# li
# ahref="coyright.html"style="color:#FFFFFF;"target="_blank"著作權聲明a
# li
# li
# ahref="aboutus.html"style="color:#FFFFFF;"target="_blank"關於我們a
# li
# li
# ahref="1536223982-688478b05681a795fa9df223e2857cd2.df"style="color:#FFFFFF;"target="_blank"合作提案a
# li
# ul
# divdivclass="newsDialog"
# divclass="dialog"
# !--你不能错过的新闻开始--
# divdata-widget_id="ml6dR2o4"id="dablewidget_ml6dR2o4"
# scrit
# (function(d,a,b,l,e,_){
# if(d[b]&&d[b].q)return;
# d[b]=function(){
# (d[b].q=d[b].q||[]).ush(arguments)
# };
# e=a.createElement(l);
# e.async=1;
# e.charset='utf-8';
# e.src='static.dable.iodistlugin.min.js?v=20200620015227';
# _=a.getElementsByTagName(l)[0];
# _.arentNode.insertBefore(e,_);
# })(window,document,'dable','scrit');
# dable('renderWidget','dablewidget_ml6dR2o4');
# scrit
# div
# !--你不能错过的新闻结束--
# div
# divdivclass="dialog"
# !--你不能错过的新闻开始--
# divdata-widget_id="ml6dR2o4"id="dablewidget_ml6dR2o4"
# scrit
# (function(d,a,b,l,e,_){
# if(d[b]&&d[b].q)return;
# d[b]=function(){
# (d[b].q=d[b].q||[]).ush(arguments)
# };
# e=a.createElement(l);
# e.async=1;
# e.charset='utf-8';
# e.src='static.dable.iodistlugin.min.js?v=20200620015227';
# _=a.getElementsByTagName(l)[0];
# _.arentNode.insertBefore(e,_);
# })(window,document,'dable','scrit');
# dable('renderWidget','dablewidget_ml6dR2o4');
# scrit
# div
# !--你不能错过的新闻结束--
# divdivdata-widget_id="ml6dR2o4"id="dablewidget_ml6dR2o4"
# scrit
# (function(d,a,b,l,e,_){
# if(d[b]&&d[b].q)return;
# d[b]=function(){
# (d[b].q=d[b].q||[]).ush(arguments)
# };
# e=a.createElement(l);
# e.async=1;
# e.charset='utf-8';
# e.src='static.dable.iodistlugin.min.js?v=20200620015227';
# _=a.getElementsByTagName(l)[0];
# _.arentNode.insertBefore(e,_);
# })(window,document,'dable','scrit');
# dable('renderWidget','dablewidget_ml6dR2o4');
# scrit
# div

# %%
#取內容試探
title=soup.find_all('title')
article=soup.find_all('div')
#article.pop(0) #三立新聞刪除記者名字
gama=soup.get_text()
beta=gama.split('(function (d, a, b, l, e, _)')[0].split('NOWnews關鍵字')[0].split('insertBefore(s, el)')[1].split('\n大')[1]
r=beta.strip()
r1= re.compile(r'[<p> /]')
r= r1.sub('' ,r )
print(r)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-32-f47c4dd09263> in <module>
#       4 #article.pop(0) #三立新聞刪除記者名字
#       5 gama=soup.get_text()
# ----> 6 beta=gama.split('(function (d, a, b, l, e, _)')[0].split('NOWnews關鍵字')[0].split('insertBefore(s, el)')[1].split('\n大')[1]
#       7 r=beta.strip()
#       8 r1= re.compile(r'[<p> /]')
#
# IndexError: list index out of range
